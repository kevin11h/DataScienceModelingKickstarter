# %% [markdown]
# A big thanks to (A) Dan Misener and his KickBack Machine project that helps users view past KickStarter projects and (B) Jared Halpert (github handle: ghostsnstuff) and his kickstarter-crawler/Crapi scraper tool for providing past crowdfunding platform datasets from both KickStarter and IndieGoGo and (C) Jeanne Pi for her 45K KickStarter dataset! <br />
# In other words, we have more than enough data we can use in our analysis to create a model! <br />
# 1. http://misener.org/introducing-the-kickback-machine/ <br />
# 2. http://www.appsblogger.com/behind-kickstarter-crowdfunding-stats/ (inspired kickstarter stats)<br /><br />
# 3. http://sidekick.epfl.ch/index/page/5/sort/elapsed/order/asc (been looking at how I can leverage their tool, but I'll work with the Americans for now)
#
# Different crowdfunding studies use different data to draw different conclusions, but we will use Dan and Jeanne's Data from KickBack Machine.<br/ >
#
# Data sources: <br />
# 1. https://www.google.com/fusiontables/DataSource?docid=15dxZcTzOdu1QyLBoF1DDd2o3ZErWxeHSUOmxWIo#rows:id1 //Dan's 2012 data<br />
# 2. https://github.com/ghostsnstuff/kickstarter-crawler // http://fierce-refuge-5919.herokuapp.com/ // https://github.com/ghostsnstuff/project-urls<br />
# 3. https://www.google.com/fusiontables/DataSource?docid=1tO8U__v4_oATOq6uo9dl-rPyg-dga3rnkZSbw9M#rows:id=1 //Jeanne Pi's 2011-2012 datascrape<br /> <br />
# 4. http://sidekick.epfl.ch/data // EPFL's Vincent Etter has a ks tracker tool that claims to have up to 84% model accuracy<br />
#
# We'll download the dataset as a csv and load it into pandas

# %% [markdown]
# We'll keep in mind these statistics for a baseline comparison: https://www.kickstarter.com/help/stats <br />
# and more kickstarter stats : <br />
# https://www.kickstarter.com/blog/trends-in-pricing-and-duration

# %% [markdown]
# ### Data Wrangling!

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
from IPython.display import Image

# %matplotlib inline
pd.options.display.mpl_style = 'default'

pd.set_option('display.max_columns', 144)
print pd.__version__

# %load_ext rpy2.ipython
# Out:
# 0.15.1

# %%
DM_KS_DF = pd.read_csv('kickscrape22may2012.csv')

# %%
JP_KS_DF = pd.read_csv('kickstarterscrape06022012.csv')

# %%
print 'Dan\'s May 2012 scrape has %d records'% len(DM_KS_DF)
print 'The columns are: '
np.array(DM_KS_DF.columns.tolist()).reshape((len(DM_KS_DF.columns), 1))
# Out:
# Dan's May 2012 scrape has 27399 records
# The columns are:
# array([['money_raised'],
#        ['parent_category'],
#        ['link'],
#        ['duration'],
#        ['in_progress'],
#        ['goal'],
#        ['category'],
#        ['visit_id'],
#        ['percent_raised'],
#        ['name'],
#        ['success'],
#        ['visit_status'],
#        ['reward_levels'],
#        ['reward_count'],
#        ['updates_count'],
#        ['comments_count'],
#        ['location'],
#        ['backers_count'],
#        ['deadline']],
#       dtype='|S15')

# %%
print 'Jeanne\'s June 2012 scrape has %d records'% len(JP_KS_DF)
print 'The columns are: '
np.array(JP_KS_DF.columns.tolist()).reshape((len(JP_KS_DF.columns), 1))
print 'Jeanne\'s status columns has %d classes: ' % len(JP_KS_DF.status.unique()), JP_KS_DF.status.unique()
print 'Let\'s set the successful and failed statuses to Boolean values for classification'

def set_successful_to_true_and_failed_to_false(status):
    if status == 'successful':
        return True
    elif status == 'failed':
        return False
    else:
        return status

JP_KS_DF.status = JP_KS_DF.status.apply(set_successful_to_true_and_failed_to_false)
# Out:
# Jeanne's June 2012 scrape has 45815 records
# The columns are:
# Jeanne's status columns has 5 classes:  ['successful' 'failed' 'live' 'canceled' 'suspended']
# Let's set the successful and failed statuses to Boolean values for classification

# %% [markdown]
# The plan is to select the pertinent features to use in our machine learning modeling task. We need to:
# 1. Drop the unpertinent columns
# 2. Rename the columns in both DM and JP so they are consistent
# 3. Drop projects with missing data
# 4. Encode categorical values into numerical ones. (child and parent categories status)

# %%
PERTINENT_FEATURES = ['name', 'goal', 'pledged',
                      'backers_count', 'duration', 'parent_category',
                      'child_category', 'levels_count', 'updates_count',
                      'comments_count', 'successful']

DM_PERTINENT_FEATURES = ['name', 'goal', 'money_raised', 
                         'backers_count', 'duration',  'parent_category',
                         'category', 'reward_count', 'updates_count',
                         'comments_count', 'success']

JP_PERTINENT_FEATURES = ['name', 'goal', 'pledged',
                         'backers', 'duration', 'category',
                         'subcategory', 'levels', 'updates',
                         'comments', 'status']

DM_KS_DF = DM_KS_DF[DM_PERTINENT_FEATURES]
JP_KS_DF = JP_KS_DF[JP_PERTINENT_FEATURES]

DM_KS_DF.columns = PERTINENT_FEATURES
JP_KS_DF.columns = PERTINENT_FEATURES

# %%
indefinite_statuses = ['live', 'canceled', 'suspended']
has_indefinite_statuses = JP_KS_DF.successful.isin(indefinite_statuses)

indices_pledged_nan = np.isnan(JP_KS_DF.pledged)
assert (indices_pledged_nan.nonzero()[0] ==  pd.isnull(JP_KS_DF).any(1).nonzero()[0]).all()
print 'JP\'s projects with missing pledges all have a status of: ', JP_KS_DF[indices_pledged_nan].successful.unique()

JP_KS_DF.drop(JP_KS_DF.index[has_indefinite_statuses.nonzero()[0]], inplace=True)
print 'After dropping projects with indefinite statuses, the number of projects with missing data is: %d' % len(pd.isnull(JP_KS_DF).any(1).nonzero()[0])
print 'JP\'s now has %d projects with complete data' % len(JP_KS_DF)

# remember to reindex a DataFrame's indices after dropping records
n_nonnull_indices = len(JP_KS_DF)
JP_KS_DF.index = list(range(n_nonnull_indices))
# Out:
# JP's projects with missing pledges all have a status of:  ['live']
# After dropping projects with indefinite statuses, the number of projects with missing data is: 0
# JP's now has 41841 projects with complete data

# %%
def one_of_k_encode_parent_category(df):
    for parent_category in sorted(df.parent_category.unique()):
        colname = ''.join(parent_category.lower().split()).replace('amp;', '')
        df['its_' + colname] = map(lambda par_cat_val : 1 if par_cat_val == parent_category else 0,
                                   df.parent_category)
        df['not_' + colname] = 1 - df['its_' + colname]
        
def one_of_k_encode_child_category(df):
    for child_category in sorted(df.child_category.unique()):
        colname = ''.join(child_category.lower().split()).replace('amp;', '')
        df['its_' + colname] = map(lambda child_cat_val : 1 if child_cat_val == child_category else 0,
                                   df.child_category)
        df['not_' + colname] = 1 - df['its_' + colname]
        
one_of_k_encode_parent_category(DM_KS_DF)
one_of_k_encode_parent_category(JP_KS_DF)
one_of_k_encode_child_category(DM_KS_DF)
one_of_k_encode_child_category(JP_KS_DF)

# %%
print 'Is DM\'s datascrape complete?'
print pd.notnull(DM_KS_DF).all()

print
print 'Is JP\'s datascrape complete?'
print pd.notnull(JP_KS_DF).all()

print
print DM_KS_DF.info()
print
print JP_KS_DF.info()
# Out:
# Is DM's datascrape complete?
# name               True
# goal               True
# pledged            True
# backers_count      True
# duration           True
# parent_category    True
# child_category     True
# levels_count       True
# updates_count      True
# comments_count     True
# successful         True
# its_art            True
# not_art            True
# its_comics         True
# not_comics         True
# ...
# not_productdesign    True
# its_publicart        True
# not_publicart        True
# its_rock             True
# not_rock             True
# its_sculpture        True
# not_sculpture        True
# its_shortfilm        True
# not_shortfilm        True
# its_videogames       True
# not_videogames       True
# its_webseries        True
# not_webseries        True
# its_worldmusic       True
# not_worldmusic       True
# Length: 109, dtype: bool
# Is JP's datascrape complete?
# name               True
# goal               True
# pledged            True
# backers_count      True
# duration           True
# parent_category    True
# child_category     True
# levels_count       True
# updates_count      True
# comments_count     True
# successful         True
# its_art            True
# not_art            True
# its_comics         True
# not_comics         True
# ...
# not_productdesign    True
# its_publicart        True
# not_publicart        True
# its_rock             True
# not_rock             True
# its_sculpture        True
# not_sculpture        True
# its_shortfilm        True
# not_shortfilm        True
# its_videogames       True
# not_videogames       True
# its_webseries        True
# not_webseries        True
# its_worldmusic       True
# not_worldmusic       True
# Length: 109, dtype: bool
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27399 entries, 0 to 27398
# Columns: 109 entries, name to not_worldmusic
# dtypes: bool(1), float64(3), int64(102), object(3)
# memory usage: 22.8+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41841 entries, 0 to 41840
# Columns: 109 entries, name to not_worldmusic
# dtypes: float64(3), int64(102), object(4)
# memory usage: 35.1+ MB
# None

# %% [markdown]
# ### Yay! Our data is now clean and complete, let's begin exploring

# %%
DM_KS_DF.describe()
# Out:
#                   goal          pledged  backers_count      duration  \
# count     27399.000000     27399.000000   27399.000000  27399.000000
# mean       8060.556001      7646.836660     106.512062     38.038641
# std       98569.819526     73055.689418     877.112757     16.195213
# min           0.010000         0.000000       0.000000      1.000000
# 25%        1500.000000      1200.000000      22.000000     30.000000
# 50%        3000.000000      3020.200000      45.000000     31.000000
# 75%        7000.000000      6322.095000      87.000000     45.000000
# max    15000000.000000  10266845.740000   87142.000000     91.958333
#
#        levels_count  updates_count  comments_count successful       its_art  \
# count  27399.000000   27399.000000    27399.000000      27399  27399.000000
# mean       8.460528       5.784153       12.603416  0.8609438      0.026169
# std        4.512399       7.331835      215.999148  0.3460114      0.159640
# min        0.000000       0.000000        0.000000      False      0.000000
# 25%        6.000000       1.000000        0.000000          1      0.000000
# 50%        8.000000       4.000000        2.000000          1      0.000000
# 75%       10.000000       8.000000        5.000000          1      0.000000
# max      138.000000     142.000000    19170.000000       True      1.000000
#
#             not_art    its_comics    not_comics     its_dance     not_dance  \
# count  27399.000000  27399.000000  27399.000000  27399.000000  27399.000000
# mean       0.973831      0.024234      0.975766      0.021242      0.978758
# std        0.159640      0.153779      0.153779      0.144192      0.144192
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      1.000000      0.000000      1.000000
# 50%        1.000000      0.000000      1.000000      0.000000      1.000000
# 75%        1.000000      0.000000      1.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#          its_design    not_design   its_fashion   not_fashion  its_film&video  \
# count  27399.000000  27399.000000  27399.000000  27399.000000    27399.000000
# mean       0.005840      0.994160      0.017446      0.982554        0.044637
# std        0.076195      0.076195      0.130928      0.130928        0.206509
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%        0.000000      1.000000      0.000000      1.000000        0.000000
# 50%        0.000000      1.000000      0.000000      1.000000        0.000000
# 75%        0.000000      1.000000      0.000000      1.000000        0.000000
# max        1.000000      1.000000      1.000000      1.000000        1.000000
#
#        not_film&video      its_food      not_food     its_games     not_games  \
# count    27399.000000  27399.000000  27399.000000  27399.000000  27399.000000
# mean         0.955363      0.028979      0.971021      0.006095      0.993905
# std          0.206509      0.167751      0.167751      0.077834      0.077834
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%          1.000000      0.000000      1.000000      0.000000      1.000000
# 50%          1.000000      0.000000      1.000000      0.000000      1.000000
# 75%          1.000000      0.000000      1.000000      0.000000      1.000000
# max          1.000000      1.000000      1.000000      1.000000      1.000000
#
#           its_music     not_music  its_photography  not_photography  \
# count  27399.000000  27399.000000     27399.000000     27399.000000
# mean       0.088616      0.911384         0.030111         0.969889
# std        0.284194      0.284194         0.170895         0.170895
# min        0.000000      0.000000         0.000000         0.000000
# 25%        0.000000      1.000000         0.000000         1.000000
# 50%        0.000000      1.000000         0.000000         1.000000
# 75%        0.000000      1.000000         0.000000         1.000000
# max        1.000000      1.000000         1.000000         1.000000
#
#        its_publishing  not_publishing  its_technology  not_technology  \
# count    27399.000000    27399.000000    27399.000000    27399.000000
# mean         0.011862        0.988138        0.006570        0.993430
# std          0.108266        0.108266        0.080788        0.080788
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        1.000000        0.000000        1.000000
# 50%          0.000000        1.000000        0.000000        1.000000
# 75%          0.000000        1.000000        0.000000        1.000000
# max          1.000000        1.000000        1.000000        1.000000
#
#         its_theater   not_theater  its_animation  not_animation   its_artbook  \
# count  27399.000000  27399.000000   27399.000000   27399.000000  27399.000000
# mean       0.070222      0.929778       0.006752       0.993248      0.007081
# std        0.255525      0.255525       0.081895       0.081895      0.083849
# min        0.000000      0.000000       0.000000       0.000000      0.000000
# 25%        0.000000      1.000000       0.000000       1.000000      0.000000
# 50%        0.000000      1.000000       0.000000       1.000000      0.000000
# 75%        0.000000      1.000000       0.000000       1.000000      0.000000
# max        1.000000      1.000000       1.000000       1.000000      1.000000
#
#         not_artbook  its_board&cardgames  not_board&cardgames  \
# count  27399.000000         27399.000000         27399.000000
# mean       0.992919             0.012154             0.987846
# std        0.083849             0.109574             0.109574
# min        0.000000             0.000000             0.000000
# 25%        1.000000             0.000000             1.000000
# 50%        1.000000             0.000000             1.000000
# 75%        1.000000             0.000000             1.000000
# max        1.000000             1.000000             1.000000
#
#        its_children'sbook  not_children'sbook  its_classicalmusic  \
# count        27399.000000        27399.000000        27399.000000
# mean             0.010000            0.990000            0.013212
# std              0.099502            0.099502            0.114184
# min              0.000000            0.000000            0.000000
# 25%              0.000000            1.000000            0.000000
# 50%              0.000000            1.000000            0.000000
# 75%              0.000000            1.000000            0.000000
# max              1.000000            1.000000            1.000000
#
#        not_classicalmusic  its_conceptualart  not_conceptualart  \
# count        27399.000000       27399.000000       27399.000000
# mean             0.986788           0.004599           0.995401
# std              0.114184           0.067659           0.067659
# min              0.000000           0.000000           0.000000
# 25%              1.000000           0.000000           1.000000
# 50%              1.000000           0.000000           1.000000
# 75%              1.000000           0.000000           1.000000
# max              1.000000           1.000000           1.000000
#
#        its_country&folk  not_country&folk    its_crafts    not_crafts  \
# count      27399.000000      27399.000000  27399.000000  27399.000000
# mean           0.029089          0.970911      0.004745      0.995255
# std            0.168058          0.168058      0.068719      0.068719
# min            0.000000          0.000000      0.000000      0.000000
# 25%            0.000000          1.000000      0.000000      1.000000
# 50%            0.000000          1.000000      0.000000      1.000000
# 75%            0.000000          1.000000      0.000000      1.000000
# max            1.000000          1.000000      1.000000      1.000000
#
#        its_digitalart  not_digitalart  its_documentary  not_documentary  \
# count    27399.000000    27399.000000     27399.000000     27399.000000
# mean         0.002883        0.997117         0.075660         0.924340
# std          0.053620        0.053620         0.264458         0.264458
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        1.000000         0.000000         1.000000
# 50%          0.000000        1.000000         0.000000         1.000000
# 75%          0.000000        1.000000         0.000000         1.000000
# max          1.000000        1.000000         1.000000         1.000000
#
#        its_electronicmusic  not_electronicmusic   its_fiction   not_fiction  \
# count         27399.000000         27399.000000  27399.000000  27399.000000
# mean              0.006497             0.993503      0.018066      0.981934
# std               0.080341             0.080341      0.133194      0.133194
# min               0.000000             0.000000      0.000000      0.000000
# 25%               0.000000             1.000000      0.000000      1.000000
# 50%               0.000000             1.000000      0.000000      1.000000
# 75%               0.000000             1.000000      0.000000      1.000000
# max               1.000000             1.000000      1.000000      1.000000
#
#        its_graphicdesign  not_graphicdesign   its_hip-hop   not_hip-hop  \
# count       27399.000000       27399.000000  27399.000000  27399.000000
# mean            0.004088           0.995912      0.007701      0.992299
# std             0.063806           0.063806      0.087418      0.087418
# min             0.000000           0.000000      0.000000      0.000000
# 25%             0.000000           1.000000      0.000000      1.000000
# 50%             0.000000           1.000000      0.000000      1.000000
# 75%             0.000000           1.000000      0.000000      1.000000
# max             1.000000           1.000000      1.000000      1.000000
#
#        its_illustration  not_illustration  its_indierock  not_indierock  \
# count      27399.000000      27399.000000   27399.000000   27399.000000
# mean           0.004927          0.995073       0.053396       0.946604
# std            0.070022          0.070022       0.224826       0.224826
# min            0.000000          0.000000       0.000000       0.000000
# 25%            0.000000          1.000000       0.000000       1.000000
# 50%            0.000000          1.000000       0.000000       1.000000
# 75%            0.000000          1.000000       0.000000       1.000000
# max            1.000000          1.000000       1.000000       1.000000
#
#            its_jazz      not_jazz  its_journalism  not_journalism  \
# count  27399.000000  27399.000000    27399.000000    27399.000000
# mean       0.011898      0.988102        0.008613        0.991387
# std        0.108430      0.108430        0.092410        0.092410
# min        0.000000      0.000000        0.000000        0.000000
# 25%        0.000000      1.000000        0.000000        1.000000
# 50%        0.000000      1.000000        0.000000        1.000000
# 75%        0.000000      1.000000        0.000000        1.000000
# max        1.000000      1.000000        1.000000        1.000000
#
#        its_mixedmedia  not_mixedmedia  its_narrativefilm  not_narrativefilm  \
# count    27399.000000    27399.000000       27399.000000       27399.000000
# mean         0.009526        0.990474           0.030220           0.969780
# std          0.097136        0.097136           0.171195           0.171195
# min          0.000000        0.000000           0.000000           0.000000
# 25%          0.000000        1.000000           0.000000           1.000000
# 50%          0.000000        1.000000           0.000000           1.000000
# 75%          0.000000        1.000000           0.000000           1.000000
# max          1.000000        1.000000           1.000000           1.000000
#
#        its_nonfiction  not_nonfiction  its_openhardware  not_openhardware  \
# count    27399.000000    27399.000000      27399.000000      27399.000000
# mean         0.018066        0.981934          0.004197          0.995803
# std          0.133194        0.133194          0.064651          0.064651
# min          0.000000        0.000000          0.000000          0.000000
# 25%          0.000000        1.000000          0.000000          1.000000
# 50%          0.000000        1.000000          0.000000          1.000000
# 75%          0.000000        1.000000          0.000000          1.000000
# max          1.000000        1.000000          1.000000          1.000000
#
#        its_opensoftware  not_opensoftware  its_painting  not_painting  \
# count      27399.000000      27399.000000  27399.000000  27399.000000
# mean           0.003358          0.996642      0.010511      0.989489
# std            0.057850          0.057850      0.101986      0.101986
# min            0.000000          0.000000      0.000000      0.000000
# 25%            0.000000          1.000000      0.000000      1.000000
# 50%            0.000000          1.000000      0.000000      1.000000
# 75%            0.000000          1.000000      0.000000      1.000000
# max            1.000000          1.000000      1.000000      1.000000
#
#        its_performanceart  not_performanceart  its_periodical  not_periodical  \
# count        27399.000000        27399.000000    27399.000000    27399.000000
# mean             0.012044            0.987956        0.005730        0.994270
# std              0.109085            0.109085        0.075482        0.075482
# min              0.000000            0.000000        0.000000        0.000000
# 25%              0.000000            1.000000        0.000000        1.000000
# 50%              0.000000            1.000000        0.000000        1.000000
# 75%              0.000000            1.000000        0.000000        1.000000
# max              1.000000            1.000000        1.000000        1.000000
#
#          its_poetry    not_poetry       its_pop       not_pop  \
# count  27399.000000  27399.000000  27399.000000  27399.000000
# mean       0.004015      0.995985      0.018504      0.981496
# std        0.063236      0.063236      0.134769      0.134769
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      0.000000      1.000000
# 50%        0.000000      1.000000      0.000000      1.000000
# 75%        0.000000      1.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000
#
#        its_productdesign  not_productdesign  its_publicart  not_publicart  \
# count       27399.000000       27399.000000   27399.000000   27399.000000
# mean            0.018066           0.981934       0.014636       0.985364
# std             0.133194           0.133194       0.120091       0.120091
# min             0.000000           0.000000       0.000000       0.000000
# 25%             0.000000           1.000000       0.000000       1.000000
# 50%             0.000000           1.000000       0.000000       1.000000
# 75%             0.000000           1.000000       0.000000       1.000000
# max             1.000000           1.000000       1.000000       1.000000
#
#            its_rock      not_rock  its_sculpture  not_sculpture  \
# count  27399.000000  27399.000000   27399.000000   27399.000000
# mean       0.045914      0.954086       0.008102       0.991898
# std        0.209303      0.209303       0.089650       0.089650
# min        0.000000      0.000000       0.000000       0.000000
# 25%        0.000000      1.000000       0.000000       1.000000
# 50%        0.000000      1.000000       0.000000       1.000000
# 75%        0.000000      1.000000       0.000000       1.000000
# max        1.000000      1.000000       1.000000       1.000000
#
#        its_shortfilm  not_shortfilm  its_videogames  not_videogames  \
# count   27399.000000   27399.000000    27399.000000    27399.000000
# mean        0.089930       0.910070        0.014234        0.985766
# std         0.286087       0.286087        0.118457        0.118457
# min         0.000000       0.000000        0.000000        0.000000
# 25%         0.000000       1.000000        0.000000        1.000000
# 50%         0.000000       1.000000        0.000000        1.000000
# 75%         0.000000       1.000000        0.000000        1.000000
# max         1.000000       1.000000        1.000000        1.000000
#
#        its_webseries  not_webseries  its_worldmusic  not_worldmusic
# count   27399.000000   27399.000000     27399.00000     27399.00000
# mean        0.019453       0.980547         0.01011         0.98989
# std         0.138114       0.138114         0.10004         0.10004
# min         0.000000       0.000000         0.00000         0.00000
# 25%         0.000000       1.000000         0.00000         1.00000
# 50%         0.000000       1.000000         0.00000         1.00000
# 75%         0.000000       1.000000         0.00000         1.00000
# max         1.000000       1.000000         1.00000         1.00000

# %%
JP_KS_DF.describe()
# Out:
#                   goal          pledged  backers_count      duration  \
# count     41841.000000     41841.000000   41841.000000  41841.000000
# mean      10410.836260      5128.665185      71.098731     40.232153
# std      148036.288998     59161.790574     713.994952     17.786219
# min           0.010000         0.000000       0.000000      1.000000
# 25%        1650.000000       220.000000       5.000000     30.000000
# 50%        4000.000000      1450.000000      25.000000     32.080000
# 75%        8800.000000      4400.000000      61.000000     49.080000
# max    21474836.470000  10266845.000000   87142.000000     91.960000
#
#        levels_count  updates_count  comments_count       its_art  \
# count  41841.000000   41841.000000    41841.000000  41841.000000
# mean       7.950646       4.335580        8.327287      0.024091
# std        4.192497       6.628569      175.451017      0.153334
# min        0.000000       0.000000        0.000000      0.000000
# 25%        5.000000       0.000000        0.000000      0.000000
# 50%        7.000000       2.000000        1.000000      0.000000
# 75%       10.000000       6.000000        3.000000      0.000000
# max       80.000000     149.000000    19311.000000      1.000000
#
#             not_art    its_comics    not_comics     its_dance     not_dance  \
# count  41841.000000  41841.000000  41841.000000  41841.000000  41841.000000
# mean       0.975909      0.023064      0.976936      0.016826      0.983174
# std        0.153334      0.150107      0.150107      0.128619      0.128619
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      1.000000      0.000000      1.000000
# 50%        1.000000      0.000000      1.000000      0.000000      1.000000
# 75%        1.000000      0.000000      1.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#          its_design    not_design   its_fashion   not_fashion  its_film&video  \
# count  41841.000000  41841.000000  41841.000000  41841.000000    41841.000000
# mean       0.006214      0.993786      0.024330      0.975670        0.055759
# std        0.078585      0.078585      0.154074      0.154074        0.229458
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%        0.000000      1.000000      0.000000      1.000000        0.000000
# 50%        0.000000      1.000000      0.000000      1.000000        0.000000
# 75%        0.000000      1.000000      0.000000      1.000000        0.000000
# max        1.000000      1.000000      1.000000      1.000000        1.000000
#
#        not_film&video      its_food      not_food     its_games     not_games  \
# count    41841.000000  41841.000000  41841.000000  41841.000000  41841.000000
# mean         0.944241      0.030855      0.969145      0.005712      0.994288
# std          0.229458      0.172927      0.172927      0.075363      0.075363
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%          1.000000      0.000000      1.000000      0.000000      1.000000
# 50%          1.000000      0.000000      1.000000      0.000000      1.000000
# 75%          1.000000      0.000000      1.000000      0.000000      1.000000
# max          1.000000      1.000000      1.000000      1.000000      1.000000
#
#           its_music     not_music  its_photography  not_photography  \
# count  41841.000000  41841.000000     41841.000000     41841.000000
# mean       0.071700      0.928300         0.032982         0.967018
# std        0.257994      0.257994         0.178592         0.178592
# min        0.000000      0.000000         0.000000         0.000000
# 25%        0.000000      1.000000         0.000000         1.000000
# 50%        0.000000      1.000000         0.000000         1.000000
# 75%        0.000000      1.000000         0.000000         1.000000
# max        1.000000      1.000000         1.000000         1.000000
#
#        its_publishing  not_publishing  its_technology  not_technology  \
# count    41841.000000    41841.000000    41841.000000    41841.000000
# mean         0.014722        0.985278        0.007839        0.992161
# std          0.120441        0.120441        0.088193        0.088193
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        1.000000        0.000000        1.000000
# 50%          0.000000        1.000000        0.000000        1.000000
# 75%          0.000000        1.000000        0.000000        1.000000
# max          1.000000        1.000000        1.000000        1.000000
#
#         its_theater   not_theater  its_animation  not_animation   its_artbook  \
# count  41841.000000  41841.000000   41841.000000   41841.000000  41841.000000
# mean       0.055329      0.944671       0.008986       0.991014      0.007194
# std        0.228623      0.228623       0.094371       0.094371      0.084512
# min        0.000000      0.000000       0.000000       0.000000      0.000000
# 25%        0.000000      1.000000       0.000000       1.000000      0.000000
# 50%        0.000000      1.000000       0.000000       1.000000      0.000000
# 75%        0.000000      1.000000       0.000000       1.000000      0.000000
# max        1.000000      1.000000       1.000000       1.000000      1.000000
#
#         not_artbook  its_board&cardgames  not_board&cardgames  \
# count  41841.000000         41841.000000         41841.000000
# mean       0.992806             0.011257             0.988743
# std        0.084512             0.105501             0.105501
# min        0.000000             0.000000             0.000000
# 25%        1.000000             0.000000             1.000000
# 50%        1.000000             0.000000             1.000000
# 75%        1.000000             0.000000             1.000000
# max        1.000000             1.000000             1.000000
#
#        its_children'sbook  not_children'sbook  its_classicalmusic  \
# count        41841.000000        41841.000000        41841.000000
# mean             0.012954            0.987046            0.010277
# std              0.113077            0.113077            0.100854
# min              0.000000            0.000000            0.000000
# 25%              0.000000            1.000000            0.000000
# 50%              0.000000            1.000000            0.000000
# 75%              0.000000            1.000000            0.000000
# max              1.000000            1.000000            1.000000
#
#        not_classicalmusic  its_conceptualart  not_conceptualart  \
# count        41841.000000       41841.000000       41841.000000
# mean             0.989723           0.003991           0.996009
# std              0.100854           0.063051           0.063051
# min              0.000000           0.000000           0.000000
# 25%              1.000000           0.000000           1.000000
# 50%              1.000000           0.000000           1.000000
# 75%              1.000000           0.000000           1.000000
# max              1.000000           1.000000           1.000000
#
#        its_country&folk  not_country&folk    its_crafts    not_crafts  \
# count      41841.000000      41841.000000  41841.000000  41841.000000
# mean           0.023589          0.976411      0.005449      0.994551
# std            0.151768          0.151768      0.073618      0.073618
# min            0.000000          0.000000      0.000000      0.000000
# 25%            0.000000          1.000000      0.000000      1.000000
# 50%            0.000000          1.000000      0.000000      1.000000
# 75%            0.000000          1.000000      0.000000      1.000000
# max            1.000000          1.000000      1.000000      1.000000
#
#        its_digitalart  not_digitalart  its_documentary  not_documentary  \
# count    41841.000000    41841.000000     41841.000000     41841.000000
# mean         0.003203        0.996797         0.087809         0.912191
# std          0.056502        0.056502         0.283020         0.283020
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        1.000000         0.000000         1.000000
# 50%          0.000000        1.000000         0.000000         1.000000
# 75%          0.000000        1.000000         0.000000         1.000000
# max          1.000000        1.000000         1.000000         1.000000
#
#        its_electronicmusic  not_electronicmusic   its_fiction   not_fiction  \
# count         41841.000000         41841.000000  41841.000000  41841.000000
# mean              0.006429             0.993571      0.022538      0.977462
# std               0.079924             0.079924      0.148426      0.148426
# min               0.000000             0.000000      0.000000      0.000000
# 25%               0.000000             1.000000      0.000000      1.000000
# 50%               0.000000             1.000000      0.000000      1.000000
# 75%               0.000000             1.000000      0.000000      1.000000
# max               1.000000             1.000000      1.000000      1.000000
#
#        its_graphicdesign  not_graphicdesign   its_hip-hop   not_hip-hop  \
# count       41841.000000       41841.000000  41841.000000  41841.000000
# mean            0.003896           0.996104      0.010038      0.989962
# std             0.062295           0.062295      0.099687      0.099687
# min             0.000000           0.000000      0.000000      0.000000
# 25%             0.000000           1.000000      0.000000      1.000000
# 50%             0.000000           1.000000      0.000000      1.000000
# 75%             0.000000           1.000000      0.000000      1.000000
# max             1.000000           1.000000      1.000000      1.000000
#
#        its_illustration  not_illustration  its_indierock  not_indierock  \
# count      41841.000000      41841.000000   41841.000000   41841.000000
# mean           0.004469          0.995531       0.043307       0.956693
# std            0.066704          0.066704       0.203549       0.203549
# min            0.000000          0.000000       0.000000       0.000000
# 25%            0.000000          1.000000       0.000000       1.000000
# 50%            0.000000          1.000000       0.000000       1.000000
# 75%            0.000000          1.000000       0.000000       1.000000
# max            1.000000          1.000000       1.000000       1.000000
#
#            its_jazz      not_jazz  its_journalism  not_journalism  \
# count  41841.000000  41841.000000    41841.000000    41841.000000
# mean       0.009895      0.990105        0.009656        0.990344
# std        0.098979      0.098979        0.097789        0.097789
# min        0.000000      0.000000        0.000000        0.000000
# 25%        0.000000      1.000000        0.000000        1.000000
# 50%        0.000000      1.000000        0.000000        1.000000
# 75%        0.000000      1.000000        0.000000        1.000000
# max        1.000000      1.000000        1.000000        1.000000
#
#        its_mixedmedia  not_mixedmedia  its_narrativefilm  not_narrativefilm  \
# count    41841.000000    41841.000000       41841.000000       41841.000000
# mean         0.009727        0.990273           0.033651           0.966349
# std          0.098147        0.098147           0.180332           0.180332
# min          0.000000        0.000000           0.000000           0.000000
# 25%          0.000000        1.000000           0.000000           1.000000
# 50%          0.000000        1.000000           0.000000           1.000000
# 75%          0.000000        1.000000           0.000000           1.000000
# max          1.000000        1.000000           1.000000           1.000000
#
#        its_nonfiction  not_nonfiction  its_openhardware  not_openhardware  \
# count    41841.000000    41841.000000      41841.000000      41841.000000
# mean         0.021056        0.978944          0.004063          0.995937
# std          0.143572        0.143572          0.063613          0.063613
# min          0.000000        0.000000          0.000000          0.000000
# 25%          0.000000        1.000000          0.000000          1.000000
# 50%          0.000000        1.000000          0.000000          1.000000
# 75%          0.000000        1.000000          0.000000          1.000000
# max          1.000000        1.000000          1.000000          1.000000
#
#        its_opensoftware  not_opensoftware  its_painting  not_painting  \
# count      41841.000000      41841.000000  41841.000000  41841.000000
# mean           0.005593          0.994407      0.011544      0.988456
# std            0.074575          0.074575      0.106821      0.106821
# min            0.000000          0.000000      0.000000      0.000000
# 25%            0.000000          1.000000      0.000000      1.000000
# 50%            0.000000          1.000000      0.000000      1.000000
# 75%            0.000000          1.000000      0.000000      1.000000
# max            1.000000          1.000000      1.000000      1.000000
#
#        its_performanceart  not_performanceart  its_periodical  not_periodical  \
# count        41841.000000        41841.000000    41841.000000    41841.000000
# mean             0.010994            0.989006        0.006286        0.993714
# std              0.104276            0.104276        0.079034        0.079034
# min              0.000000            0.000000        0.000000        0.000000
# 25%              0.000000            1.000000        0.000000        1.000000
# 50%              0.000000            1.000000        0.000000        1.000000
# 75%              0.000000            1.000000        0.000000        1.000000
# max              1.000000            1.000000        1.000000        1.000000
#
#          its_poetry    not_poetry       its_pop       not_pop  \
# count  41841.000000  41841.000000  41841.000000  41841.000000
# mean       0.004780      0.995220      0.016491      0.983509
# std        0.068973      0.068973      0.127356      0.127356
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      0.000000      1.000000
# 50%        0.000000      1.000000      0.000000      1.000000
# 75%        0.000000      1.000000      0.000000      1.000000
# max        1.000000      1.000000      1.000000      1.000000
#
#        its_productdesign  not_productdesign  its_publicart  not_publicart  \
# count       41841.000000       41841.000000   41841.000000   41841.000000
# mean            0.021749           0.978251       0.012165       0.987835
# std             0.145865           0.145865       0.109624       0.109624
# min             0.000000           0.000000       0.000000       0.000000
# 25%             0.000000           1.000000       0.000000       1.000000
# 50%             0.000000           1.000000       0.000000       1.000000
# 75%             0.000000           1.000000       0.000000       1.000000
# max             1.000000           1.000000       1.000000       1.000000
#
#            its_rock      not_rock  its_sculpture  not_sculpture  \
# count  41841.000000  41841.000000   41841.000000   41841.000000
# mean       0.038885      0.961115       0.007863       0.992137
# std        0.193324      0.193324       0.088326       0.088326
# min        0.000000      0.000000       0.000000       0.000000
# 25%        0.000000      1.000000       0.000000       1.000000
# 50%        0.000000      1.000000       0.000000       1.000000
# 75%        0.000000      1.000000       0.000000       1.000000
# max        1.000000      1.000000       1.000000       1.000000
#
#        its_shortfilm  not_shortfilm  its_videogames  not_videogames  \
# count   41841.000000   41841.000000    41841.000000    41841.000000
# mean        0.089267       0.910733        0.017925        0.982075
# std         0.285131       0.285131        0.132681        0.132681
# min         0.000000       0.000000        0.000000        0.000000
# 25%         0.000000       1.000000        0.000000        1.000000
# 50%         0.000000       1.000000        0.000000        1.000000
# 75%         0.000000       1.000000        0.000000        1.000000
# max         1.000000       1.000000        1.000000        1.000000
#
#        its_webseries  not_webseries  its_worldmusic  not_worldmusic
# count   41841.000000   41841.000000    41841.000000    41841.000000
# mean        0.024474       0.975526        0.009130        0.990870
# std         0.154516       0.154516        0.095114        0.095114
# min         0.000000       0.000000        0.000000        0.000000
# 25%         0.000000       1.000000        0.000000        1.000000
# 50%         0.000000       1.000000        0.000000        1.000000
# 75%         0.000000       1.000000        0.000000        1.000000
# max         1.000000       1.000000        1.000000        1.000000

# %%
JP_KS_DF.successful.describe()
# Out:
# count     41841
# unique        2
# top        True
# freq      22902
# Name: successful, dtype: object

# %% [markdown]
# It look's like Dan's May 2012 datascrape has more successful entries (~80%) where as Leanne's has a more reasonable distribution. <br />
# We'll work with her ~42K cleaned and preprocessed data to be safe, and after all it was her analysis that initially led on KickStarter to publish public stats <br />Jeanne's sample, based on success ratio, is a better representation

# %% [markdown]
# ### Partitioning of Project Data into Training, CrossValidation, and Test Sets

# %% [markdown]
# We'll try out a 10-10-80 partitioning scheme for now

# %%
np.random.seed(42)

N = len(JP_KS_DF)
randomperm = np.random.permutation(N)

print 'need to split about (%f, %f, %f) = (train, cv, test) for %d records' % (.1*N, .1*N, .8*N, sum([.1*N, .1*N, .8*N]))
# Out:
# need to split about (4184.100000, 4184.100000, 33472.800000) = (train, cv, test) for 41841 records

# %%
TRAIN_SET_INDICES = randomperm[0:4184]
CV_SET_INDICES = randomperm[4184:8368]
TEST_SET_INDICES = randomperm[8368:N]

TRAIN_DF = JP_KS_DF.ix[TRAIN_SET_INDICES]
CV_DF = JP_KS_DF.ix[CV_SET_INDICES]
TEST_DF = JP_KS_DF.ix[TEST_SET_INDICES]

# %% [markdown]
# ### Factor Analysis

# %% [markdown]
# I want to study the relationship between the features, then formulate a model that captures that relationship.

# %% [markdown]
# Let's build and visualize a correlation matrix of the features! <br />
# Each entry of the correlation matrix has the form:

# %% [markdown]
# ### $$\begin{aligned}\rho_{X, Y} &= \mathrm{Corr}(X, Y) = {\mathrm{Cov}(X, Y) \over \sqrt{ Var(X) \mathrm{ } Var(Y) } } = {\mathrm{Cov}(X, Y) \over {\sigma_X \mathrm{ } \sigma_Y } } = {E[(X-\mu_X)(Y-\mu_Y)] \over \sigma_X\sigma_Y} \mathrm{,} \\
# & \mathrm{where } -1 \leq \rho_{X, Y} \leq 1 \end{aligned}$$

# %%
noncomputational_columns = ['name', 'parent_category', 'child_category']
is_computational = lambda c : c not in noncomputational_columns
doesnt_start_with_not = lambda c : not c.startswith('not')

def get_computational_columns(df):
    computational_columns = filter(lambda c : is_computational(c) and doesnt_start_with_not(c), df.columns)
    
    if 'successful' in computational_columns:
        i = computational_columns.index('successful')
        del computational_columns[i]
        computational_columns.append('successful')
        
    return computational_columns
        
def to_matrix_4_ML(df):
    computational_columns = get_computational_columns(df)
    return df[computational_columns].as_matrix()

# %%
def center_feature_matrix(feature_matrix):
    mean_project = feature_matrix.mean(axis=0)
    return feature_matrix - mean_project

def get_normalization_factor(feature_matrix):
    n_samples, k_features = feature_matrix.shape
    norm = np.float64(n_samples-1)
    return norm

def calculate_correlation_matrix(feature_matrix):
    centered_feature_matrix = center_feature_matrix(feature_matrix)
    norm = get_normalization_factor(centered_feature_matrix)
    Cov = np.dot(centered_feature_matrix.T, centered_feature_matrix) / norm

    variances = np.diag(Cov)
    Corr = Cov / np.sqrt(np.outer(variances, variances).astype(np.float64))
    
    return Corr

# %%
training_matrix = to_matrix_4_ML(TRAIN_DF)
Corr = calculate_correlation_matrix(training_matrix)

# %% [markdown]
# Numpy and Scipy have correlation, covariance, PCA and eigenvalue decomposition routines, and we might use them later on, but it is important to learn what they are calculating. Let's compare our function with numpy's corrcoef:

# %%
Rho = np.corrcoef(training_matrix.T.astype(np.float64))
Rho.min(), Rho.max(), Corr.min(), Corr.max()
# Out:
# (-0.15222573046842158, 1.0, -0.15222573046841772, 1.0)

# %% [markdown]
# Another good check is to see if the eigenvalues of Corr/Rho are positive which means that it is indeed a positive semidefinite matrix

# %%
import plotly.plotly as py
import plotly.tools as tls
from plotly.graph_objs import *

py.sign_in('kevin11h', 'ilrcfqwrng')

# %%
def columns_2_labels_4_viz(columns):
    labels = []
    
    for c in columns:
        if str(c).startswith('its_'):
            c = c[len('its_'):]
        
        if str(c).endswith('_count'):
            c = c[0:-len('_count')]
            
        c = c[0].upper() + c[1:]
        labels.append(c)
        
    return labels    

trace = Heatmap(z=Corr,
                x=columns_2_labels_4_viz(get_computational_columns(TRAIN_DF)),
                y=columns_2_labels_4_viz(get_computational_columns(TRAIN_DF)),
                zauto=False,
                zmin = Corr.min(),
                zmax = Corr.max(),
                colorscale='YIOrRd',
                reversescale=True)

data = Data([trace])

title = 'Feature Correlations of KickStarter Projects in June 2012 with Categories'
data_src_url = 'http://www.appsblogger.com/behind-kickstarter-crowdfunding-stats/'
annotation_text = 'Source and for more information: <a href="%s">Jeanne on Appsblogger</a>' % data_src_url

layout = Layout(title=title,
                autosize=False,
                height=500,
                width=600,
                annotations=Annotations([Annotation(text=annotation_text,
                                         xref='paper',
                                         yref='paper',
                                         xanchor='right',
                                         yanchor='bottom',
                                         x=.75,
                                         y=1)])
                )

fig = Figure(data=data, layout=layout)

url = py.plot(fig, filename='ks_feature_corr_cat', auto_open=False)
print url
py.iplot(fig, filename='ks_feature_corr_cat')
# Out:
# https://plot.ly/~kevin11h/20

# %% [markdown]
# The heatmap is hard to read because of all 49 categories that are weakly related and of duplicate information since the Correlation matrix is symmetric, so let's improve the situation:

# %%
def exclude_categories(columns):
    return filter(lambda c : not str(c).startswith('its'), columns)

reduced_computational_columns = exclude_categories(get_computational_columns(TRAIN_DF))
reduced_training_matrix = TRAIN_DF[reduced_computational_columns].as_matrix()
Corr2 = calculate_correlation_matrix(reduced_training_matrix)
reduced_training_df = DataFrame(reduced_training_matrix, columns=reduced_computational_columns)
reduced_training_df.to_csv('reduced_training_matrix.csv', index=False)
reduced_training_df_without_successful_column = reduced_training_df[filter(lambda c : c is not 'successful', reduced_computational_columns)]
reduced_training_df.head(len(reduced_computational_columns))
# Out:
#     goal pledged backers_count duration levels_count updates_count  \
# 0   1000    1110            38    41.22            6             3
# 1   5000     535             8       30            7             0
# 2  10000     821            12       90           10             6
# 3   2000    2032            50       30            7             3
# 4   4000     712            20       45            7             2
# 5   2500    3508            72    35.29            6             2
# 6   2200    2410            29    20.95            5             2
# 7   5500     921            15    29.96            9            26
#
#   comments_count successful
# 0              0       True
# 1              0      False
# 2              3      False
# 3              8       True
# 4              2      False
# 5              2       True
# 6              6       True
# 7              3      False

# %%
def triangularize_symmetric_matrix(x, y, z):
    x_new = x[0:-1]
    y_new = y[-1:0:-1]
    tmp = np.empty(z.shape)
    tmp.fill(np.nan)
    for i in range(len(z)):
        tmp[i, 0 :i] = z[i, 0:i]
    tmp = np.flipud(tmp)
    z_new = tmp
    return (x_new, y_new, z_new)

(x, y, z) = triangularize_symmetric_matrix(columns_2_labels_4_viz(exclude_categories(get_computational_columns(TRAIN_DF))),
                                           columns_2_labels_4_viz(exclude_categories(get_computational_columns(TRAIN_DF))),
                                           Corr2)

trace = Heatmap(z=z,
                x=x,
                y=y,
                zauto=False,
                zmax = Corr2.max(),
                zmin = Corr2.min(),
                colorscale=[[0,'#CC0000'], [.5, '#CC00CC'], [1, '#3333CC']],
                reversescale=True,
                colorbar=ColorBar(titleside='bottom',
                                  title='   %f'%Corr2.min()))

data = Data([trace])

title = 'Feature Correlations of KickStarter Projects in June 2012'
data_src_url = 'http://www.appsblogger.com/behind-kickstarter-crowdfunding-stats/'
annotation_text = 'Source and for more information: <a href="%s">Jeanne on Appsblogger</a>' % data_src_url

layout = Layout(title=title,
                autosize=False,
                height=500,
                width=600,
                annotations=Annotations([Annotation(text=annotation_text,
                                         xref='paper',
                                         yref='paper',
                                         xanchor='right',
                                         yanchor='bottom',
                                         x=.75,
                                         y=1)])
                )
axis_style = {'autotick':False,'showgrid':False,'showline':False}
layout.update(xaxis=XAxis(axis_style, tickangle=90))
layout.update(yaxis=YAxis(axis_style))

fig = Figure(data=data, layout=layout)

url = py.plot(fig, filename='ks_feature_corr', auto_open=False)
print url
py.iplot(fig, filename='ks_feature_corr')
# Out:
# https://plot.ly/~kevin11h/19

# %% [markdown]
# By the heatmap we can see that 6 relation pairs have a correlation of $\geq$ 0.2: <br />
# {(Pledged, Backers), (Backers, Pledged), (Pledged, Comments), (Backers, Comments), (Comments, Updates), (Comments, Levels), (Levels, Updates), (Updates, Successful)}

# %%
# %install_ext http://www.ipp.mpg.de/~mkraus/python/tikzmagic.py
# Out:
# Installed tikzmagic.py. To use it, type:
#   %load_ext tikzmagic

# %%
# %load_ext tikzmagic

# %% [markdown]
# There is the tikzmagic extension and D3 and Networkx people use to create beautiful graph visualizations, but I'll be more traditional and post a screenshot of what I coded in LaTeX.

# %% [markdown]
# ### Correlation Inference Graph

# %%
Image(filename='./correlation_inference_graph.png')

# %% [markdown]
# In analyzing the correlation between features, I made educated assumptions about the causality between the moderately and strongly correlated ones. <br />
# IE:
# 1. The size of Backers determines the number of comments made and the amount pledged,
# 2. People who pledge usually make comments and ask Q&A questions about the product to the creators, so that's the Pledges -> Comments edge
# 3. The levels of rewards instigate comments/Q&A and affects the creator's routine updates
# 4. More updates usually mean the project's fundraising is successfully met and the creator's are rewarding their backers.

# %% [markdown]
# Now, let's also visualize the correlations as a matrix of scatterplots, where each project is a point:

# %%
import seaborn as sns
sns.set()

sns.pairplot(TRAIN_DF[reduced_computational_columns], hue='successful', size=2.5)
plt.gcf().savefig('ks_feature_scatter_matrix.png')

# %% [markdown]
# In many factor pairs, it looks like 2 clusters can easily be discriminated. I'll continue with this in mind, and further analyze the factors with PCA

# %%
# %%R
# reduced_training_matrix <- read.csv('corr2.csv')#'reduced_training_matrix.csv')
# reduced_training_matrix$successful <- NULL

# %%
# %%R
# #reduced_training_matrix.stand <- as.data.frame(scale(reduced_training_matrix))
# pca <- princomp(reduced_training_matrix)
# summary(pca)
# Out:
# Importance of components:
#                           Comp.1    Comp.2    Comp.3     Comp.4     Comp.5
# Standard deviation     0.6438851 0.4075903 0.3380082 0.26855230 0.20488187
# Proportion of Variance 0.4987643 0.1998602 0.1374463 0.08676337 0.05049934
# Cumulative Proportion  0.4987643 0.6986245 0.8360708 0.92283419 0.97333353
#                           Comp.6       Comp.7
# Standard deviation     0.1488043 4.821443e-03
# Proportion of Variance 0.0266385 2.796615e-05
# Cumulative Proportion  0.9999720 1.000000e+00

# %%
# %%R
# plot(pca, main="Scree Plot of KS Features", type="lines") # scree plot
# title(xlab="Features")

# %% [markdown]
# Looks like the top 3 components can explain ~68% of the variance, let's take a look at the component loadings to see how much each feature is responsible for

# %%
# %%R
# pca$loading
# Out:
# Loadings:
#                Comp.1 Comp.2 Comp.3 Comp.4 Comp.5 Comp.6 Comp.7
# goal                  -0.408  0.775  0.234        -0.412
# pledged        -0.612                       0.344 -0.181  0.677
# backers_count  -0.613                       0.226 -0.184 -0.731
# duration        0.198 -0.577 -0.518 -0.286        -0.527
# levels_count    0.147  0.379  0.291 -0.710  0.423 -0.257
# updates_count   0.179  0.581 -0.185  0.439        -0.627
# comments_count -0.387  0.129        -0.393 -0.799 -0.165
#
#                Comp.1 Comp.2 Comp.3 Comp.4 Comp.5 Comp.6 Comp.7
# SS loadings     1.000  1.000  1.000  1.000  1.000  1.000  1.000
# Proportion Var  0.143  0.143  0.143  0.143  0.143  0.143  0.143
# Cumulative Var  0.143  0.286  0.429  0.571  0.714  0.857  1.000

# %% [markdown]
# For PC1, the primary component loadings are pledged, backers_count, and comments_count<br />
# For PC2, the primary component loadings are goal, duration, levels_count, and updates_count<br /><br />
# For PC3, the primary component loadings are goal, duration, and levels_count<br />
#
# But the Loading Matrix seems like it's missing some data. We'll use Python's PCA to check with R's results, and make loading plots as well.

# %%
from sklearn.decomposition import PCA
corr_reduced_training_matrix_without_successful_column = np.corrcoef(reduced_training_matrix[:, :-1].T.astype(np.float64))
pca_fit_model = PCA().fit(corr_reduced_training_matrix_without_successful_column)

# %%
plt.figure(figsize=(12,8))
plt.bar(np.arange(7)+1, pca_fit_model.explained_variance_ratio_.cumsum(), width=.99)
plt.ylim((0,1))
plt.xlim((1,7.9))
plt.xlabel('PC by decreasing eigenvalue')
plt.ylabel('Cumulative Explained Variance')

# %%
loadings_df = DataFrame(pca_fit_model.components_.T,
                        index = reduced_training_df_without_successful_column.columns,
                        columns = ['PC%d'%(i+1) for i in range(7)])
loadings_df
# Out:
#                      PC1       PC2       PC3       PC4       PC5       PC6  \
# goal           -0.144015 -0.260937 -0.800574 -0.210940 -0.046811 -0.446025
# pledged         0.603140 -0.080964  0.043760 -0.102927  0.347426  0.033915
# backers_count   0.604134 -0.044563  0.025233 -0.069576  0.229221 -0.426132
# duration       -0.255933 -0.554181  0.517782  0.175932  0.011187 -0.547101
# levels_count   -0.160791  0.508284 -0.131838  0.637864  0.423546 -0.318328
# updates_count  -0.147726  0.573725  0.266007 -0.615065 -0.082828 -0.414120
# comments_count  0.370575  0.169531 -0.017046  0.352055 -0.798865 -0.214883
#
#                      PC7
# goal            0.156934
# pledged         0.703778
# backers_count  -0.627238
# duration        0.169959
# levels_count    0.104010
# updates_count   0.146957
# comments_count  0.159188

# %% [markdown]
# For PC1, the primary component loadings are pledged, backers_count, and comments_count<br />
# For PC2, the primary component loadings are goal, duration, levels_count, and updates_count<br />
# For PC3, the primary component loadings are goal, duration, and updates_count<br /> <br />
# Seems like features fall into 2 categories: <br />
# 1. Creator Actions
# 2. Backer Actions

# %%
fig, axes = plt.subplots(nrows=1,ncols=3, figsize=(20,8))

for (ith, ax) in enumerate(axes):    
    ax.bar(np.arange(7)+1, pca_fit_model.components_[ith], width=.99)
    ax.set_title('Component Loading Plot for PC%d' % (ith+1))
    ax.set_xlabel('Feature')
    ax.set_ylabel('Value')
    ax.set_ylim((-1,1))
    ax.set_xlim(1,7.9)
    ax.set_xticklabels(reduced_computational_columns, rotation=40, ha='center')

# %% [markdown]
# Ok, we'll project the features onto 2D to view their similarity

# %%
X_proj = pca_fit_model.transform(corr_reduced_training_matrix_without_successful_column)

CREATOR_FEATURES = ['goal', 'duration', 'levels_count', 'updates_count']
BACKER_FEATURES = ['pledged', 'backers_count', 'comments_count']

feature_similarity_df = DataFrame(X_proj[:,:2], columns=['PC1', 'PC2'], index=reduced_training_df_without_successful_column.columns)

# %%
t = 'Similarity of the 7 Noncategory Features: Goal, Pledged, Backers, Duration, Levels, Updates, and Comments'
trace1 = Scatter(x=feature_similarity_df.loc[CREATOR_FEATURES].PC1,
                 y=feature_similarity_df.loc[CREATOR_FEATURES].PC2,
                 mode='markers+text', marker=Marker(symbol='triangle-down',
                                               color='green',
                                               line=Line(color='green', width=1.0),
                                               opacity=0.7), name='Creator Feature',
text=CREATOR_FEATURES)

trace2 = Scatter(x=feature_similarity_df.loc[BACKER_FEATURES].PC1,
                 y=feature_similarity_df.loc[BACKER_FEATURES].PC2,
                 mode='markers+text', marker=Marker(symbol='triangle-up',
                                               color='black',
                                               line=Line(color='black', width=1.0),
                                               opacity=0.7), name='Backer Feature',
text=BACKER_FEATURES)

data = Data([trace1, trace2])
layout = Layout(title=t,
                xaxis=XAxis(title='Projection onto PC1 (Backer Features)'),
                yaxis=YAxis(title='Projection onto PC2 (Creator Features)'))

f = Figure(data=data, layout=layout)

url = py.plot(f, filename='similarity_7_features', auto_open=False)
print url
py.iplot(f, filename='similarity_7_features')
# Out:
# https://plot.ly/~kevin11h/22

# %% [markdown]
# ### Including the successful status in PCA

# %%
corr_reduced_training_matrix_including_successful_column = np.corrcoef(reduced_training_matrix.T.astype(np.float64))
pca_fit_model2 = PCA().fit(corr_reduced_training_matrix_including_successful_column)

# %%
plt.figure(figsize=(12,8))
plt.bar(np.arange(8)+1, pca_fit_model2.explained_variance_ratio_.cumsum(), width=.99)
plt.ylim((0,1))
plt.xlim((1,8.9))
plt.xlabel('PC by decreasing eigenvalue')
plt.ylabel('Cumulative Explained Variance')

# %%
loadings_df2 = DataFrame(pca_fit_model2.components_.T,
                        index = reduced_training_df.columns,
                        columns = ['PC%d'%(i+1) for i in range(8)])
loadings_df2
# Out:
#                      PC1       PC2       PC3       PC4       PC5       PC6  \
# goal           -0.032336 -0.434824  0.596090 -0.462704  0.099834 -0.020053
# pledged         0.601058  0.085809 -0.092806 -0.084266 -0.087796 -0.356641
# backers_count   0.600924  0.100210 -0.054386 -0.048787 -0.034387 -0.252092
# duration       -0.146800 -0.475758 -0.603925  0.268700  0.077359 -0.087289
# levels_count   -0.151343  0.129635  0.469427  0.690343 -0.296797 -0.344888
# updates_count  -0.219335  0.420978  0.001102 -0.034125  0.779465 -0.376872
# comments_count  0.379619  0.096777  0.158351  0.379625  0.360326  0.696534
# successful     -0.199753  0.603145 -0.151467 -0.287004 -0.386871  0.234725
#
#                      PC7       PC8
# goal            0.450836  0.163835
# pledged        -0.084422  0.688204
# backers_count   0.389786 -0.637844
# duration        0.522905  0.167769
# levels_count    0.225192  0.074879
# updates_count   0.143797  0.056817
# comments_count  0.195626  0.155145
# successful      0.504578  0.177869

# %%
fig, axes = plt.subplots(nrows=1,ncols=3, figsize=(20,8))

for (ith, ax) in enumerate(axes):    
    ax.bar(np.arange(8)+1, pca_fit_model2.components_[ith], width=.99)
    ax.set_title('Component Loading Plot for PC%d' % (ith+1))
    ax.set_xlabel('Feature')
    ax.set_ylabel('Value')
    ax.set_ylim((-1,1))
    ax.set_xlim(1,8.9)
    ax.set_xticklabels(reduced_computational_columns, rotation=40, ha='center')

# %%
X_proj2 = pca_fit_model2.transform(corr_reduced_training_matrix_including_successful_column)

CREATOR_FEATURES = ['goal', 'duration', 'levels_count', 'updates_count']
BACKER_FEATURES = ['pledged', 'backers_count', 'comments_count']

feature_similarity_with_successful_state_df = DataFrame(X_proj2[:,:2], columns=['PC1', 'PC2'], index=reduced_training_df.columns)

# %%
t = 'Similarity of Success by 7 Noncategory Features: Goal, Pledged, Backers, Duration, Levels, Updates, and Comments'
trace1 = Scatter(x=feature_similarity_with_successful_state_df.loc[CREATOR_FEATURES].PC1,
                 y=feature_similarity_with_successful_state_df.loc[CREATOR_FEATURES].PC2,
                 mode='markers', marker=Marker(symbol='triangle-down',
                                               color='green',
                                               line=Line(color='green', width=1.0),
                                               opacity=0.7), name='Creator Feature',
text=CREATOR_FEATURES)

trace2 = Scatter(x=feature_similarity_with_successful_state_df.loc[BACKER_FEATURES].PC1,
                 y=feature_similarity_with_successful_state_df.loc[BACKER_FEATURES].PC2,
                 mode='markers', marker=Marker(symbol='triangle-up',
                                               color='black',
                                               line=Line(color='black', width=1.0),
                                               opacity=0.7), name='Backer Feature',
text=BACKER_FEATURES)

trace3 = Scatter(x=map(lambda xy : 1.2*xy, feature_similarity_with_successful_state_df.loc[CREATOR_FEATURES].PC1),
                 y=map(lambda xy : xy, feature_similarity_with_successful_state_df.loc[CREATOR_FEATURES].PC2),
                 mode='text',   text=CREATOR_FEATURES)

trace4 = Scatter(x=map(lambda xy : 1.1*xy, feature_similarity_with_successful_state_df.loc[BACKER_FEATURES].PC1),
                 y=map(lambda xy : 1.1*xy, feature_similarity_with_successful_state_df.loc[BACKER_FEATURES].PC2),
                 mode='text',  text=BACKER_FEATURES)

trace5 = Scatter(x=feature_similarity_with_successful_state_df.loc['successful'].PC1,
                 y=feature_similarity_with_successful_state_df.loc['successful'].PC2,
                 mode='markers+text', marker=Marker(symbol='circle',
                                               color='orange',
                                               size=5,
                                               line=Line(color='orange', width=1.0),
                                               opacity=0.7), text=['Successful'], name='Successful')

data = Data([trace1, trace2, trace3, trace4, trace5])
layout = Layout(title=t,
                xaxis=XAxis(title='Projection onto PC1 (Backer Features)'),
                yaxis=YAxis(title='Projection onto PC2 (Creator Features)'))

f = Figure(data=data, layout=layout)

url = py.plot(f, filename='similarity_7_features_w_successful', auto_open=False)
print url
py.iplot(f, filename='similarity_7_features_w_successful')
# Out:
# https://plot.ly/~kevin11h/23

# %% [markdown]
# Interesting! It seems that the users have the primary component of affecting the success of project funding, slightly negatively, through increasing # backers, # comments, and amount pledged. <br />
# The secondary component is optimistic for the creators who can strongly positively affect success of project funding by decreasing goal amount, duration, and increasing updates(!!!) <br />
# The third component is a strange story that a large goal amount over a short duration with many levels or rewards slightly negatively correlates with success.<br />
# All in all, success mainly lies within the creator's hands, as the successful feature is closer to the creator features.

# %% [markdown]
# ### Visualizing the Projects in reduced 2D and 3D PC Space

# %% [markdown]
# Because it's cool, and it allows us to better discriminate between (un)successful projects.

# %%
reduced_training_matrix = DataFrame.from_csv('reduced_training_matrix.csv').reset_index().as_matrix()[:,:-1].astype(np.float64)
reduced_training_matrix.shape
# Out:
# (4184, 7)

# %%
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA

normalized_reduced_training_matrix = normalize(reduced_training_matrix)
pca_fit_model_for_project_similarity_2D = PCA(n_components=2).fit(normalized_reduced_training_matrix)
pca_fit_model_for_project_similarity_3D = PCA(n_components=3).fit(normalized_reduced_training_matrix)
X_proj_2D = pca_fit_model_for_project_similarity_2D.transform(normalized_reduced_training_matrix)
X_proj_3D = pca_fit_model_for_project_similarity_3D.transform(normalized_reduced_training_matrix)
X_proj_3D.shape, X_proj_2D.shape
# Out:
# ((4184, 3), (4184, 2))

# %%
successful_indices = DataFrame.from_csv('reduced_training_matrix.csv').reset_index()['successful'].values
unsuccessful_indices = ~successful_indices

# %%
project_similarity_2D_cov = pca_fit_model_for_project_similarity_2D.get_covariance()
eigval_2D, eigvec_2D = np.linalg.eig(project_similarity_2D_cov)

project_similarity_3D_cov = pca_fit_model_for_project_similarity_2D.get_covariance()
eigval_3D, eigvec_3D = np.linalg.eig(project_similarity_3D_cov)

# %%
fig = plt.figure(figsize=(12,12))

plt.plot(X_proj_2D[successful_indices,0],
        X_proj_2D[successful_indices,1],
        'o', markersize=8, color='orange', alpha=0.5, label='Successful')

plt.plot(X_proj_2D[~successful_indices,0],
        X_proj_2D[~successful_indices,1],
        'v', markersize=8, color='blue', alpha=0.5, label='Not Successful')

#for v in eigvec_2D.T:
#    a = Arrow3D([mean_x, v[0]], [mean_y, v[1]],\
#        [mean_z, v[2]], mutation_scale=20, lw=3, arrowstyle="-|>", color="r")
#    ax.add_artist(a)

plt.legend(loc='best')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('2D PCA Project Success Similarity')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

fig = plt.figure(figsize=(12,12))
ax = fig.add_subplot(111, projection='3d')
plt.rcParams['legend.fontsize'] = 10   

ax.plot(X_proj_3D[successful_indices,0],
        X_proj_3D[successful_indices,1],
        X_proj_3D[successful_indices,2],
        'o', markersize=8, color='orange', alpha=0.5, label='Successful')

ax.plot(X_proj_3D[unsuccessful_indices,0],
        X_proj_3D[unsuccessful_indices,1],
        X_proj_3D[unsuccessful_indices,2],
        'v', markersize=8, color='blue', alpha=0.5, label='Not Successful')

ax.legend(loc='best')

plt.title('3D PCA Project Success Similarity')
plt.xlabel('PC1')
plt.ylabel('PC2')
ax.set_zlabel('PC3')
plt.show()

# %% [markdown]
# Clearly linearly separable.

# %% [markdown]
# ### Updated Correlation Inference Graph

# %% [markdown]
# The black vertices represent the creator features and the green nodes represent the backers features. Success is not a feature, instead it is a label. However it seems to be highly correlated with updates.

# %%
Image('./classified_correlation_inference_graph.png')

# %% [markdown]
# ### Developing a Bayesian Model for Classification

# %% [markdown]
# Given a project, we wish to estimate the probability of its success. <br />
# I attempt to achieve this using a Bayesian approach.

# %%
url_src = 'http://www.kickstarter.com/help/stats'
print url_src
Image('./ks_stats_goal_distribution.png')
# Out:
# http://www.kickstarter.com/help/stats

# %% [markdown]
# From the population data, the prior probability of success is $75302 \mathrm{\ successful} \over { 75302 \mathrm{\ successful} + 112667 \mathrm{\ unsuccessful} } $ $= 0.40$ not including ongoing or delayed projects, close to the 43-44% claimed rate.

# %%
successfully_funded_projects_by_goal_url = 'https://s3.amazonaws.com/ksr/assets/001/253/431/5120c144a15e7fa33f092f75d92a3180_large.png'
src = 'https://www.kickstarter.com/blog/five-million-backers'
print 'src: %s' % src
Image(url=successfully_funded_projects_by_goal_url)
# Out:
# src: https://www.kickstarter.com/blog/five-million-backers
# <img src="https://s3.amazonaws.com/ksr/assets/001/253/431/5120c144a15e7fa33f092f75d92a3180_large.png"/>

# %% [markdown]
# In the successfully funded projects table, the goal amount categories (< 1K, 1K-9K, 10K-19K, 20K-99K, 100K-999K, >= 1M) has a distribution ~ (11.41%, 60.76%, 13.90%, 11.66%, 2.15%, 0.11%) <br />
# Since we do not currently have unsuccessfully funded projects goal amount categories, we'll estimate it through our sample.

# %%
unsuccessful_goal_series = TRAIN_DF[unsuccessful_indices].goal
unsuccessful_goal_5SS = unsuccessful_goal_series.describe()
unsuccessful_goal_5SS
# Out:
# count       1899.000000
# mean       14541.457578
# std        42193.702934
# min           24.000000
# 25%         2500.000000
# 50%         5000.000000
# 75%        12000.000000
# max      1200000.000000
# Name: goal, dtype: float64

# %%
iqr = unsuccessful_goal_5SS['75%'] - unsuccessful_goal_5SS['25%']
nonoutlier_range = (unsuccessful_goal_5SS['25%'] - iqr*1.5, unsuccessful_goal_5SS['75%'] + iqr*1.5)

outlier_unsuccessful_indices = (unsuccessful_goal_series < min(nonoutlier_range)).values | (unsuccessful_goal_series > max(nonoutlier_range)).values
nonoutliers_of_unsuccessful_goal_series = unsuccessful_goal_series[~outlier_unsuccessful_indices]

print 'There are %d outliers for unsuccessful goals' % sum(outlier_unsuccessful_indices)
plt.figure(figsize=(12,8))
nonoutliers_of_unsuccessful_goal_series.hist(bins=100)
plt.title('Goal Amounts for Unsuccessful Projects')
# Out:
# There are 201 outliers for unsuccessful goals

# %%
goal_categories = ['< 1K', '1K-9K', '10K-19K', '20K-99K', '100K-999K', '>= 1M']
goal_ranges = [(0, 1000), (1000, 10000), (10000, 20000), (20000, 100000), (100000, 1000000), (1000000, np.inf)]

for (goal_category, goal_range) in zip(goal_categories, goal_ranges):
    inrange_indices = (unsuccessful_goal_series >= min(goal_range)).values & (unsuccessful_goal_series < max(goal_range)).values
    n = len(unsuccessful_goal_series[inrange_indices])
    prob = 100.0*n / len(unsuccessful_goal_series)
    print '# of unsuccessful projects with goal {0} = {1} ({2}%)'.format(goal_category, n, prob)
# Out:
# # of unsuccessful projects with goal < 1K = 158 (8.32016850974%)
# # of unsuccessful projects with goal 1K-9K = 1079 (56.8193786203%)
# # of unsuccessful projects with goal 10K-19K = 326 (17.1669299631%)
# # of unsuccessful projects with goal 20K-99K = 296 (15.5871511322%)
# # of unsuccessful projects with goal 100K-999K = 39 (2.05371248025%)
# # of unsuccessful projects with goal >= 1M = 1 (0.0526592943655%)

# %% [markdown]
# In the unsuccessfully funded projects histogram, the goal amount categories (< 1K, 1K-9K, 10K-19K, 20K-99K, 100K-999K, >= 1M) has a distribution ~ (8.3%, 56.82%, 17.17%, 15.59%, 2.05%, 0.05%) <br />
# Compared to the successfully funded projects table, the goal amount categories (< 1K, 1K-9K, 10K-19K, 20K-99K, 100K-999K, >= 1M) has a distribution ~ (11.41%, 60.76%, 13.90%, 11.66%, 2.15%, 0.11%) <br />

# %%
src_url = 'https://www.kickstarter.com/blog/shortening-the-maximum-project-length'
print src_url
Image('https://s3.amazonaws.com/ksr/assets/000/000/878/ef0ecde23270b556718ae07eb364597b_large.png')
# Out:
# https://www.kickstarter.com/blog/shortening-the-maximum-project-length

# %% [markdown]
# For successful projects, the duration categories (0-30D, 30-60D, 60-90D) has a distribution ~(0.30, 0.50, 0.20)<br />
# While unsuccessful ones, the distribution ~(0.25, 0.50, 0.25)

# %%
successful_backers_series = TRAIN_DF[successful_indices].backers_count
successful_backers_series_5SS = successful_backers_series.describe()
print successful_backers_series_5SS

iqr = successful_backers_series_5SS['75%'] - successful_backers_series_5SS['25%']
nonoutlier_range = (successful_backers_series_5SS['25%'] - iqr*1.5, successful_backers_series_5SS['75%'] + iqr*1.5)

outlier_successful_backers_indices = (successful_backers_series < min(nonoutlier_range)).values | (successful_backers_series > max(nonoutlier_range)).values
nonoutliers_of_successful_backers_series = successful_backers_series[~outlier_successful_backers_indices]

print 'There are %d outliers for successful backers' % sum(outlier_successful_backers_indices)
plt.figure(figsize=(12,8))
nonoutliers_of_successful_backers_series.hist(bins=100)
plt.title('Backer Counts for Successful Projects')
# Out:
# count     2285.00000
# mean       144.48709
# std       1521.59021
# min          1.00000
# 25%         31.00000
# 50%         54.00000
# 75%         99.00000
# max      68929.00000
# Name: backers_count, dtype: float64
# There are 207 outliers for successful backers

# %%
backer_categories = ['< 25', '25-50', '50-75', '75-100', '100+']#['< 50', '50-100', '100-150', '150-200']
backer_ranges = [(0, 25), (25,50), (50, 75), (75, 100), (100, 125), (125, 150), (150, 175), (175, 200)]

for (backer_category, backer_range) in zip(backer_categories, backer_ranges):
    inrange_indices = (successful_backers_series >= min(backer_range)).values & (successful_backers_series < max(backer_range)).values
    n = len(successful_backers_series[inrange_indices])
    prob = 100.0*n / len(successful_backers_series)
    print '# of successful_backers_series projects with backer count {0} = {1} ({2}%)'.format(backer_category, n, prob)
# Out:
# # of successful_backers_series projects with backer count < 25 = 427 (18.6870897155%)
# # of successful_backers_series projects with backer count 25-50 = 630 (27.5711159737%)
# # of successful_backers_series projects with backer count 50-75 = 430 (18.818380744%)
# # of successful_backers_series projects with backer count 75-100 = 229 (10.0218818381%)
# # of successful_backers_series projects with backer count 100+ = 144 (6.30196936543%)

# %%
unsuccessful_backers_series = TRAIN_DF[unsuccessful_indices].backers_count
unsuccessful_backers_series_5SS = unsuccessful_backers_series.describe()
print unsuccessful_backers_series_5SS

iqr = unsuccessful_backers_series_5SS['75%'] - unsuccessful_backers_series_5SS['25%']
nonoutlier_range = (unsuccessful_backers_series_5SS['25%'] - iqr*1.5, unsuccessful_backers_series_5SS['75%'] + iqr*1.5)

outlier_unsuccessful_backers_indices = (unsuccessful_backers_series < min(nonoutlier_range)).values | (unsuccessful_backers_series > max(nonoutlier_range)).values
nonoutliers_of_unsuccessful_backers_series = unsuccessful_backers_series[~outlier_unsuccessful_backers_indices]

print 'There are %d outliers for successful backers' % sum(outlier_unsuccessful_backers_indices)
plt.figure(figsize=(12,8))
nonoutliers_of_unsuccessful_backers_series.hist(bins=10)
plt.title('Backer Counts for Unsuccessful Projects')
# Out:
# count    1899.000000
# mean       11.372828
# std        23.170350
# min         0.000000
# 25%         1.000000
# 50%         4.000000
# 75%        12.000000
# max       463.000000
# Name: backers_count, dtype: float64
# There are 203 outliers for successful backers

# %%
for (backer_category, backer_range) in zip(backer_categories, backer_ranges):
    inrange_indices = (unsuccessful_backers_series >= min(backer_range)).values & (unsuccessful_backers_series < max(backer_range)).values
    n = len(unsuccessful_backers_series[inrange_indices])
    prob = 100.0*n / len(unsuccessful_backers_series)
    print '# of unsuccessful_backers_series projects with backer count {0} = {1} ({2}%)'.format(backer_category, n, prob)
# Out:
# # of unsuccessful_backers_series projects with backer count < 25 = 1656 (87.2037914692%)
# # of unsuccessful_backers_series projects with backer count 25-50 = 161 (8.47814639284%)
# # of unsuccessful_backers_series projects with backer count 50-75 = 47 (2.47498683518%)
# # of unsuccessful_backers_series projects with backer count 75-100 = 16 (0.842548709847%)
# # of unsuccessful_backers_series projects with backer count 100+ = 9 (0.473933649289%)

# %%
successful_projects_df = TRAIN_DF[successful_indices]
unsuccessful_projects_df = TRAIN_DF[unsuccessful_indices]
    
def assign_backers_bin_for_successful_or_unsuccessful_project(n_backers):
    if 0 <= n_backers < 25:
        return 1
    elif 25 <= n_backers < 50:
        return 2
    elif 50 <= n_backers < 75:
        return 3
    elif 75 <= n_backers < 100:
        return 4
    else:
        return 5

successful_projects_df['backers_bin'] = successful_projects_df.backers_count.apply(assign_backers_bin_for_successful_or_unsuccessful_project)
unsuccessful_projects_df['backers_bin'] = unsuccessful_projects_df.backers_count.apply(assign_backers_bin_for_successful_or_unsuccessful_project)

# %%
successful_pledges_and_backers_df_gb_levels = successful_projects_df[['backers_bin', 'pledged']].set_index('backers_bin')
fig, ax = plt.subplots(nrows=1, ncols=5)
fig.set_size_inches(18.5,10.5)

for i in xrange(len(successful_pledges_and_backers_df_gb_levels.index.unique())):
    pledges_of_ith_backers_bin = successful_pledges_and_backers_df_gb_levels.ix[i+1].pledged
    
    pledges_of_ith_backers_bin_5SS = pledges_of_ith_backers_bin.describe()
    print pledges_of_ith_backers_bin_5SS

    iqr = pledges_of_ith_backers_bin_5SS['75%'] - pledges_of_ith_backers_bin_5SS['25%']
    nonoutlier_range = (pledges_of_ith_backers_bin_5SS['25%'] - iqr*1.5, pledges_of_ith_backers_bin_5SS['75%'] + iqr*1.5)

    outlier_successful_pledges_given_backers_indices = (pledges_of_ith_backers_bin < min(nonoutlier_range)).values | (pledges_of_ith_backers_bin > max(nonoutlier_range)).values
    nonoutliers_of_successful_pledges_given_backers_series = pledges_of_ith_backers_bin[~outlier_successful_pledges_given_backers_indices]

    nonoutliers_of_successful_pledges_given_backers_series.hist(ax=ax[i])
    ax[i].set_title(('Successful Projects # Pledges at Backer Category %d'%(i+1)))
    
    print 'There are {0} pledges outliers for successful projects given backer category {1}'.format(sum(outlier_successful_pledges_given_backers_indices), i+1)
# Out:
# count     427.000000
# mean     1230.901639
# std      1097.957337
# min        17.000000
# 25%       547.500000
# 50%       911.000000
# 75%      1500.000000
# max      8500.000000
# Name: pledged, dtype: float64
# There are 34 pledges outliers for successful projects given backer category 1
# count      630.000000
# mean      3043.615873
# std       2893.784574
# min        220.000000
# 25%       1510.500000
# 50%       2186.500000
# 75%       3504.000000
# max      30135.000000
# Name: pledged, dtype: float64
# There are 39 pledges outliers for successful projects given backer category 2
# count      430.000000
# mean      4529.069767
# std       3039.167521
# min        440.000000
# 25%       2639.500000
# 50%       3750.500000
# 75%       5318.500000
# max      20419.000000
# Name: pledged, dtype: float64
# There are 28 pledges outliers for successful projects given backer category 3
# count      229.000000
# mean      6180.615721
# std       4743.047369
# min       1029.000000
# 25%       3565.000000
# 50%       5253.000000
# 75%       7122.000000
# max      52407.000000
# Name: pledged, dtype: float64
# There are 14 pledges outliers for successful projects given backer category 4
# count         569.000000
# mean        40915.193322
# std        435424.916992
# min          2543.000000
# 25%          7242.000000
# 50%         11060.000000
# 75%         20256.000000
# max      10266845.000000
# Name: pledged, dtype: float64
# There are 44 pledges outliers for successful projects given backer category 5

# %%
successful_pledge_given_backers_categories = ['0-4999 pledged', '50000+']
successful_pledge_given_backers_ranges = [(0,5000), (5000, np.inf)]

for backer_category_index in range(5):
    series = successful_pledges_and_backers_df_gb_levels.ix[backer_category_index+1]
    print
    
    for (pledge_category, pledge_range) in zip(successful_pledge_given_backers_categories, successful_pledge_given_backers_ranges):
        inrange_indices = (series >= min(pledge_range)).values & (series < max(pledge_range)).values
        n = len(series[inrange_indices])
        prob = 100.0*n / len(series)
        print '# of successful projects with backer category {0} and pledge amount {1} = {2} ({3}%)'.format(backer_category_index+1,
                                                                                                          pledge_category, n, prob)
# Out:
# # of successful projects with backer category 1 and pledge amount 0-4999 pledged = 417 (97.6580796253%)
# # of successful projects with backer category 1 and pledge amount 50000+ = 10 (2.34192037471%)
#
# # of successful projects with backer category 2 and pledge amount 0-4999 pledged = 528 (83.8095238095%)
# # of successful projects with backer category 2 and pledge amount 50000+ = 102 (16.1904761905%)
#
# # of successful projects with backer category 3 and pledge amount 0-4999 pledged = 289 (67.2093023256%)
# # of successful projects with backer category 3 and pledge amount 50000+ = 141 (32.7906976744%)
#
# # of successful projects with backer category 4 and pledge amount 0-4999 pledged = 102 (44.5414847162%)
# # of successful projects with backer category 4 and pledge amount 50000+ = 127 (55.4585152838%)
#
# # of successful projects with backer category 5 and pledge amount 0-4999 pledged = 45 (7.9086115993%)
# # of successful projects with backer category 5 and pledge amount 50000+ = 524 (92.0913884007%)

# %%
unsuccessful_pledges_and_backers_df_gb_levels = unsuccessful_projects_df[['backers_bin', 'pledged']].set_index('backers_bin')
fig, ax = plt.subplots(nrows=1, ncols=5)
fig.set_size_inches(18.5,10.5)

for i in xrange(len(unsuccessful_pledges_and_backers_df_gb_levels.index.unique())):
    pledges_of_ith_backers_bin = unsuccessful_pledges_and_backers_df_gb_levels.ix[i+1].pledged
    
    pledges_of_ith_backers_bin_5SS = pledges_of_ith_backers_bin.describe()
    print pledges_of_ith_backers_bin_5SS

    iqr = pledges_of_ith_backers_bin_5SS['75%'] - pledges_of_ith_backers_bin_5SS['25%']
    nonoutlier_range = (pledges_of_ith_backers_bin_5SS['25%'] - iqr*1.5, pledges_of_ith_backers_bin_5SS['75%'] + iqr*1.5)

    outlier_unsuccessful_pledges_given_backers_indices = (pledges_of_ith_backers_bin < min(nonoutlier_range)).values | (pledges_of_ith_backers_bin > max(nonoutlier_range)).values
    nonoutliers_of_unsuccessful_pledges_given_backers_series = pledges_of_ith_backers_bin[~outlier_unsuccessful_pledges_given_backers_indices]

    nonoutliers_of_unsuccessful_pledges_given_backers_series.hist(ax=ax[i])
    ax[i].set_title(('Unsuccessful Projects # Pledges at Backer Category %d'%(i+1)))
    
    print 'There are {0} pledges outliers for unsuccessful projects given backer category {1}'.format(sum(outlier_successful_pledges_given_backers_indices), i+1)
# Out:
# count     1656.000000
# mean       343.303140
# std        778.804966
# min          0.000000
# 25%          5.000000
# 50%        100.000000
# 75%        374.000000
# max      12592.000000
# Name: pledged, dtype: float64
# There are 44 pledges outliers for unsuccessful projects given backer category 1
# count      161.000000
# mean      2557.378882
# std       1866.624229
# min        566.000000
# 25%       1389.000000
# 50%       1974.000000
# 75%       3175.000000
# max      12361.000000
# Name: pledged, dtype: float64
# There are 44 pledges outliers for unsuccessful projects given backer category 2
# count       47.000000
# mean      3632.000000
# std       2221.835297
# min        470.000000
# 25%       2388.500000
# 50%       2976.000000
# 75%       4681.500000
# max      13354.000000
# Name: pledged, dtype: float64
# There are 44 pledges outliers for unsuccessful projects given backer category 3
# count       16.000000
# mean      7156.500000
# std       3375.924387
# min        378.000000
# 25%       5121.500000
# 50%       7530.000000
# 75%       9131.000000
# max      12870.000000
# Name: pledged, dtype: float64
# There are 44 pledges outliers for unsuccessful projects given backer category 4
# count       19.000000
# mean     10356.947368
# std      10178.886304
# min       2250.000000
# 25%       4370.000000
# 50%       5566.000000
# 75%      12976.500000
# max      45391.000000
# Name: pledged, dtype: float64
# There are 44 pledges outliers for unsuccessful projects given backer category 5

# %%
unsuccessful_pledge_given_backers_categories = ['0-4999 pledged', '50000+']
unsuccessful_pledge_given_backers_ranges = [(0,5000), (5000, np.inf)]

for backer_category_index in range(5):
    series = unsuccessful_pledges_and_backers_df_gb_levels.ix[backer_category_index+1]
    print
    
    for (pledge_category, pledge_range) in zip(unsuccessful_pledge_given_backers_categories, unsuccessful_pledge_given_backers_ranges):
        inrange_indices = (series >= min(pledge_range)).values & (series < max(pledge_range)).values
        n = len(series[inrange_indices])
        prob = 100.0*n / len(series)
        print '# of Unsuccessful projects with backer category {0} and pledge amount {1} = {2} ({3}%)'.format(backer_category_index+1,
                                                                                                          pledge_category, n, prob)
# Out:
# # of Unsuccessful projects with backer category 1 and pledge amount 0-4999 pledged = 1646 (99.3961352657%)
# # of Unsuccessful projects with backer category 1 and pledge amount 50000+ = 10 (0.6038647343%)
#
# # of Unsuccessful projects with backer category 2 and pledge amount 0-4999 pledged = 144 (89.4409937888%)
# # of Unsuccessful projects with backer category 2 and pledge amount 50000+ = 17 (10.5590062112%)
#
# # of Unsuccessful projects with backer category 3 and pledge amount 0-4999 pledged = 37 (78.7234042553%)
# # of Unsuccessful projects with backer category 3 and pledge amount 50000+ = 10 (21.2765957447%)
#
# # of Unsuccessful projects with backer category 4 and pledge amount 0-4999 pledged = 3 (18.75%)
# # of Unsuccessful projects with backer category 4 and pledge amount 50000+ = 13 (81.25%)
#
# # of Unsuccessful projects with backer category 5 and pledge amount 0-4999 pledged = 5 (26.3157894737%)
# # of Unsuccessful projects with backer category 5 and pledge amount 50000+ = 14 (73.6842105263%)

# %%
successful_levels_series = TRAIN_DF[successful_indices].levels_count
successful_levels_series_5SS = successful_levels_series.describe()
print successful_levels_series_5SS

iqr = successful_levels_series_5SS['75%'] - successful_levels_series_5SS['25%']
nonoutlier_range = (successful_levels_series_5SS['25%'] - iqr*1.5, successful_levels_series_5SS['75%'] + iqr*1.5)

outlier_successful_levels_indices = (successful_levels_series < min(nonoutlier_range)).values | (successful_levels_series > max(nonoutlier_range)).values
nonoutliers_of_successful_levels_series = successful_levels_series[~outlier_successful_levels_indices]

print 'There are %d outliers for successful levels' % sum(outlier_successful_levels_indices)
plt.figure(figsize=(12,8))
nonoutliers_of_successful_levels_series.hist()
plt.title('Level Counts for Successful Projects')
# Out:
# count    2285.000000
# mean        8.465208
# std         4.361032
# min         0.000000
# 25%         6.000000
# 50%         8.000000
# 75%        10.000000
# max        64.000000
# Name: levels_count, dtype: float64
# There are 94 outliers for successful levels

# %% [markdown]
# The level counts for successful project exhibit a very normal distribution

# %%
unsuccessful_levels_series = TRAIN_DF[unsuccessful_indices].levels_count
unsuccessful_levels_series_5SS = unsuccessful_levels_series.describe()
print unsuccessful_levels_series_5SS

iqr = unsuccessful_levels_series_5SS['75%'] - unsuccessful_levels_series_5SS['25%']
nonoutlier_range = (unsuccessful_levels_series_5SS['25%'] - iqr*1.5, unsuccessful_levels_series_5SS['75%'] + iqr*1.5)

outlier_unsuccessful_levels_indices = (unsuccessful_levels_series < min(nonoutlier_range)).values | (unsuccessful_levels_series > max(nonoutlier_range)).values
nonoutliers_of_unsuccessful_levels_series = unsuccessful_levels_series[~outlier_unsuccessful_levels_indices]

print 'There are %d outliers for successful levels' % sum(nonoutliers_of_unsuccessful_levels_series)
plt.figure(figsize=(12,8))
nonoutliers_of_unsuccessful_levels_series.hist()
plt.title('Level Counts for Unsuccessful Projects')
# Out:
# count    1899.000000
# mean        7.179568
# std         3.758360
# min         0.000000
# 25%         5.000000
# 50%         7.000000
# 75%         9.000000
# max        43.000000
# Name: levels_count, dtype: float64
# There are 12895 outliers for successful levels

# %% [markdown]
# The level counts for unsuccessful project exhibit a very normal distribution as well.

# %% [markdown]
# We'll measure the probability of level counts as the area of the normal distribution centered at 7 (or 8 for unsuccessful projects) along the intervals:
# 1. [-1$\sigma$, 1$\sigma$]
# 2. [-2$\sigma$, -1$\sigma$] $\cup$ [1$\sigma$, 2$\sigma$]
# 3. [-$\infty$, -2$\sigma$] $\cup$ [2$\sigma$, $\infty$]
#
# so {[4, 12], [0, 4] $\cup$ [12, 16], [16, $\infty$]} for successful projects <br />
# and {[3, 11], [0, 3] $\cup$ [11, 14], [14, $\infty$]} for unsuccessful projects

# %%
successful_projects_df = TRAIN_DF[successful_indices]

def assign_bin_for_successful_project(n_levels):
    if 4 <= n_levels < 12:
        return 1
    elif 0 <= n_levels < 4 or 12 <= n_levels < 16:
        return 2
    else:
        return 3

successful_projects_df['levels_bin'] = successful_projects_df.levels_count.apply(assign_bin_for_successful_project)

unsuccessful_projects_df = TRAIN_DF[unsuccessful_indices]

def assign_bin_for_unsuccessful_project(n_levels):
    if 3 <= n_levels < 11:
        return 1
    elif 0 <= n_levels < 3 or 11 <= n_levels < 14:
        return 2
    else:
        return 3

unsuccessful_projects_df['levels_bin'] = unsuccessful_projects_df.levels_count.apply(assign_bin_for_unsuccessful_project)

# %%
successful_updates_and_levels_df_gb_levels = successful_projects_df[['levels_bin', 'updates_count']].set_index('levels_bin')
fig, ax = plt.subplots(nrows=1, ncols=3)
fig.set_size_inches(18.5,10.5)

for i in xrange(len(successful_updates_and_levels_df_gb_levels.index.unique())):
    successful_updates_and_levels_df_gb_levels.ix[i+1].hist(ax=ax[i], bins=10, width=10)
    ax[i].set_title(('Successful Projects # Updates at Level Category %d'%(i+1)))

# %%
successful_update_categories = ['0-9 updates', '10-19 updates', '20-29 updates', '30+ updates']
successful_update_ranges = [(0,10), (10,20), (20,30), (30, np.inf)]

for level_category_index in range(3):
    print
    for (update_category, update_range) in zip(successful_update_categories, successful_update_ranges):
        inrange_indices = (successful_updates_and_levels_df_gb_levels.ix[level_category_index+1] >= min(update_range)).values &(successful_updates_and_levels_df_gb_levels.ix[level_category_index+1] < max(update_range)).values
        n = len(successful_updates_and_levels_df_gb_levels.ix[level_category_index+1][inrange_indices])
        prob = 100.0*n / len(successful_updates_and_levels_df_gb_levels.ix[level_category_index+1])
        print '# of successful projects with level category {0} and update count {1} = {2} ({3}%)'.format(level_category_index+1,
                                                                                                          update_category, n, prob)
# Out:
# # of successful projects with level category 1 and update count 0-9 updates = 1367 (76.9707207207%)
# # of successful projects with level category 1 and update count 10-19 updates = 306 (17.2297297297%)
# # of successful projects with level category 1 and update count 20-29 updates = 77 (4.33558558559%)
# # of successful projects with level category 1 and update count 30+ updates = 26 (1.46396396396%)
#
# # of successful projects with level category 2 and update count 0-9 updates = 280 (72.7272727273%)
# # of successful projects with level category 2 and update count 10-19 updates = 73 (18.961038961%)
# # of successful projects with level category 2 and update count 20-29 updates = 18 (4.67532467532%)
# # of successful projects with level category 2 and update count 30+ updates = 14 (3.63636363636%)
#
# # of successful projects with level category 3 and update count 0-9 updates = 68 (54.8387096774%)
# # of successful projects with level category 3 and update count 10-19 updates = 37 (29.8387096774%)
# # of successful projects with level category 3 and update count 20-29 updates = 10 (8.06451612903%)
# # of successful projects with level category 3 and update count 30+ updates = 9 (7.25806451613%)

# %%
unsuccessful_updates_and_levels_df_gb_levels = unsuccessful_projects_df[['levels_bin', 'updates_count']].set_index('levels_bin')
fig, ax = plt.subplots(nrows=1, ncols=3)
fig.set_size_inches(18.5,10.5)

for i in xrange(len(unsuccessful_updates_and_levels_df_gb_levels.index.unique())):
    unsuccessful_updates_and_levels_df_gb_levels.ix[i+1].hist(ax=ax[i], bins=10)
    ax[i].set_title(('Unsuccessful Projects # Updates at Level Category %d'%(i+1)))

# %%
unsuccessful_update_categories = ['0-4 updates', '5-9 updates', '10+ updates']
unsuccessful_update_ranges = [(0,5), (5,10), (10,np.inf)]

for level_category_index in range(3):
    print
    for (update_category, update_range) in zip(unsuccessful_update_categories, unsuccessful_update_ranges):
        inrange_indices = (unsuccessful_updates_and_levels_df_gb_levels.ix[level_category_index+1] >= min(update_range)).values &(unsuccessful_updates_and_levels_df_gb_levels.ix[level_category_index+1] < max(update_range)).values
        n = len(unsuccessful_updates_and_levels_df_gb_levels.ix[level_category_index+1][inrange_indices])
        prob = 100.0*n / len(unsuccessful_updates_and_levels_df_gb_levels.ix[level_category_index+1])
        print '# of unsuccessful projects with level category {0} and update count {1} = {2} ({3}%)'.format(level_category_index+1,
                                                                                                          update_category, n, prob)
# Out:
# # of unsuccessful projects with level category 1 and update count 0-4 updates = 1340 (91.5300546448%)
# # of unsuccessful projects with level category 1 and update count 5-9 updates = 92 (6.28415300546%)
# # of unsuccessful projects with level category 1 and update count 10+ updates = 32 (2.18579234973%)
#
# # of unsuccessful projects with level category 2 and update count 0-4 updates = 314 (89.4586894587%)
# # of unsuccessful projects with level category 2 and update count 5-9 updates = 26 (7.40740740741%)
# # of unsuccessful projects with level category 2 and update count 10+ updates = 11 (3.1339031339%)
#
# # of unsuccessful projects with level category 3 and update count 0-4 updates = 58 (69.0476190476%)
# # of unsuccessful projects with level category 3 and update count 5-9 updates = 17 (20.2380952381%)
# # of unsuccessful projects with level category 3 and update count 10+ updates = 9 (10.7142857143%)

# %%
def assign_pledges_bin_for_project(pledge_amount):
    if pledge_amount < 5000:
        return 1
    else:
        return 2

successful_projects_df['pledges_bin'] = successful_projects_df.pledged.apply(assign_pledges_bin_for_project)
unsuccessful_projects_df['pledges_bin'] = unsuccessful_projects_df.pledged.apply(assign_pledges_bin_for_project)

# %%
levels_of_successful_projects_by_backers_and_pledges = successful_projects_df.set_index(['backers_bin', 'pledges_bin'])

# %%
successful_projects_df['pledges_bin'] = successful_projects_df.pledged.apply(assign_pledges_bin_for_project)
successful_projects_df['levels_bin'] = successful_projects_df.levels_count.apply(assign_bin_for_successful_project)
successful_projects_df['backers_bin'] = successful_projects_df.backers_count.apply(assign_backers_bin_for_successful_or_unsuccessful_project)

fig, ax = plt.subplots(nrows=6, ncols=5)
fig.set_size_inches(18.5,10.5)

successful_projects_df_by_backers_pledges_and_levels = successful_projects_df[['backers_bin', 'pledges_bin', 'levels_bin', 'comments_count']].set_index(['backers_bin', 'pledges_bin', 'levels_bin'])
grid = [(level_category+1, pledge_category+1, backer_category+1) for backer_category in range(5) for pledge_category in range(2) for level_category in range(3)]
for (i, (level_category, pledge_category, backer_category)) in enumerate(grid):
    try:
        df = successful_projects_df_by_backers_pledges_and_levels.ix[backer_category].ix[pledge_category].ix[level_category]
        df.hist(ax=ax[i/5, i%5])
        ax[i/5, i%5].set_title('Successful Projects \n# Comments at \nBacker Category {0}\n Pledge Category {1}\n Level Category {2}'.format(backer_category, pledge_category, level_category))
    except BaseException:
        print (i/5, i%5)
        ax[i/5, i%5].set_title('Successful Projects \n# Comments at \nBacker Category {0}\n Pledge Category {1}\n Level Category {2}'.format(backer_category, pledge_category, level_category))
        continue
# Out:
# (0, 4)
# (1, 0)
# (5, 1)

# %% [markdown]
# Cool! We'll set the successful comments interval as:
# 1. [0, 3]
# 2. [4, 10]
# 3. [11, 20]
# 4. [21, 30]
# 5. [30, $\infty$]

# %%
successful_comments_categories = ['0-3 comments', '4-10 comments', '11-20 comments', '21-30 comments', '30+ comments']
successful_comments_ranges = [(0,4), (4,11), (11,21), (21, 30), (31, np.inf)]

print '# successful projects subject to:'

for backer_category in range(5):
    
    for pledge_category in range(2):
        
        for level_category in range(3):
            print
            for (successful_comments_category, successful_comments_range) in zip(successful_comments_categories, successful_comments_ranges):
                inrange_indices = (successful_updates_and_levels_df_gb_levels.ix[level_category_index+1] >= min(update_range)).values &(successful_updates_and_levels_df_gb_levels.ix[level_category_index+1] < max(update_range)).values

                try:
                    df = successful_projects_df_by_backers_pledges_and_levels.ix[backer_category+1].ix[pledge_category+1].ix[level_category+1]
                    inrange_indices = (df >= min(successful_comments_range)).values & (df < max(successful_comments_range)).values
                    n = len(df[inrange_indices])
                    prob = 100.0*n/len(df)
                    print '{5} & backer category {0} & pledge category {1} & level category {2} = {3} ({4}%)'.format(backer_category+1,
                                                                                                                                                 pledge_category+1,
                                                                                                                                                 level_category+1,
                                                                                                                                                 n, prob, successful_comments_category)
                    
                except BaseException as detail:
                    print '{5} & backer category {0} & pledge category {1} & level category {2} = {3} ({4}%)'.format(backer_category+1,
                                                                                                                                                 pledge_category+1,
                                                                                                                                                 level_category+1,
                                                                                                                                                 0, 0.0, successful_comments_category)
# Out:
# # successful projects subject to:
#
# 0-3 comments & backer category 1 & pledge category 1 & level category 1 = 291 (90.3726708075%)
# 4-10 comments & backer category 1 & pledge category 1 & level category 1 = 28 (8.69565217391%)
# 11-20 comments & backer category 1 & pledge category 1 & level category 1 = 3 (0.931677018634%)
# 21-30 comments & backer category 1 & pledge category 1 & level category 1 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 1 & level category 1 = 0 (0.0%)
#
# 0-3 comments & backer category 1 & pledge category 1 & level category 2 = 82 (92.1348314607%)
# 4-10 comments & backer category 1 & pledge category 1 & level category 2 = 6 (6.74157303371%)
# 11-20 comments & backer category 1 & pledge category 1 & level category 2 = 1 (1.12359550562%)
# 21-30 comments & backer category 1 & pledge category 1 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 1 & level category 2 = 0 (0.0%)
#
# 0-3 comments & backer category 1 & pledge category 1 & level category 3 = 4 (66.6666666667%)
# 4-10 comments & backer category 1 & pledge category 1 & level category 3 = 2 (33.3333333333%)
# 11-20 comments & backer category 1 & pledge category 1 & level category 3 = 0 (0.0%)
# 21-30 comments & backer category 1 & pledge category 1 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 1 & level category 3 = 0 (0.0%)
#
# 0-3 comments & backer category 1 & pledge category 2 & level category 1 = 8 (80.0%)
# 4-10 comments & backer category 1 & pledge category 2 & level category 1 = 1 (10.0%)
# 11-20 comments & backer category 1 & pledge category 2 & level category 1 = 1 (10.0%)
# 21-30 comments & backer category 1 & pledge category 2 & level category 1 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 2 & level category 1 = 0 (0.0%)
#
# 0-3 comments & backer category 1 & pledge category 2 & level category 2 = 0 (0.0%)
# 4-10 comments & backer category 1 & pledge category 2 & level category 2 = 0 (0.0%)
# 11-20 comments & backer category 1 & pledge category 2 & level category 2 = 0 (0.0%)
# 21-30 comments & backer category 1 & pledge category 2 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 2 & level category 2 = 0 (0.0%)
#
# 0-3 comments & backer category 1 & pledge category 2 & level category 3 = 0 (0.0%)
# 4-10 comments & backer category 1 & pledge category 2 & level category 3 = 0 (0.0%)
# 11-20 comments & backer category 1 & pledge category 2 & level category 3 = 0 (0.0%)
# 21-30 comments & backer category 1 & pledge category 2 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 2 & level category 3 = 0 (0.0%)
# 0-3 comments & backer category 2 & pledge category 1 & level category 1 = 357 (78.6343612335%)
# 4-10 comments & backer category 2 & pledge category 1 & level category 1 = 89 (19.6035242291%)
# 11-20 comments & backer category 2 & pledge category 1 & level category 1 = 8 (1.76211453744%)
# 21-30 comments & backer category 2 & pledge category 1 & level category 1 = 0 (0.0%)
# 30+ comments & backer category 2 & pledge category 1 & level category 1 = 0 (0.0%)
#
# 0-3 comments & backer category 2 & pledge category 1 & level category 2 = 45 (75.0%)
# 4-10 comments & backer category 2 & pledge category 1 & level category 2 = 12 (20.0%)
# 11-20 comments & backer category 2 & pledge category 1 & level category 2 = 3 (5.0%)
# 21-30 comments & backer category 2 & pledge category 1 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 2 & pledge category 1 & level category 2 = 0 (0.0%)
#
# 0-3 comments & backer category 2 & pledge category 1 & level category 3 = 12 (85.7142857143%)
# 4-10 comments & backer category 2 & pledge category 1 & level category 3 = 0 (0.0%)
# 11-20 comments & backer category 2 & pledge category 1 & level category 3 = 2 (14.2857142857%)
# 21-30 comments & backer category 2 & pledge category 1 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 2 & pledge category 1 & level category 3 = 0 (0.0%)
#
# 0-3 comments & backer category 2 & pledge category 2 & level category 1 = 65 (80.2469135802%)
# 4-10 comments & backer category 2 & pledge category 2 & level category 1 = 16 (19.7530864198%)
# 11-20 comments & backer category 2 & pledge category 2 & level category 1 = 0 (0.0%)
# 21-30 comments & backer category 2 & pledge category 2 & level category 1 = 0 (0.0%)
# 30+ comments & backer category 2 & pledge category 2 & level category 1 = 0 (0.0%)
#
# 0-3 comments & backer category 2 & pledge category 2 & level category 2 = 11 (64.7058823529%)
# 4-10 comments & backer category 2 & pledge category 2 & level category 2 = 6 (35.2941176471%)
# 11-20 comments & backer category 2 & pledge category 2 & level category 2 = 0 (0.0%)
# 21-30 comments & backer category 2 & pledge category 2 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 2 & pledge category 2 & level category 2 = 0 (0.0%)
#
# 0-3 comments & backer category 2 & pledge category 2 & level category 3 = 2 (50.0%)
# 4-10 comments & backer category 2 & pledge category 2 & level category 3 = 2 (50.0%)
# 11-20 comments & backer category 2 & pledge category 2 & level category 3 = 0 (0.0%)
# 21-30 comments & backer category 2 & pledge category 2 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 2 & pledge category 2 & level category 3 = 0 (0.0%)
#
# 0-3 comments & backer category 3 & pledge category 1 & level category 1 = 152 (65.5172413793%)
# 4-10 comments & backer category 3 & pledge category 1 & level category 1 = 62 (26.724137931%)
# 11-20 comments & backer category 3 & pledge category 1 & level category 1 = 15 (6.46551724138%)
# 21-30 comments & backer category 3 & pledge category 1 & level category 1 = 2 (0.862068965517%)
# 30+ comments & backer category 3 & pledge category 1 & level category 1 = 1 (0.431034482759%)
# 0-3 comments & backer category 3 & pledge category 1 & level category 2 = 28 (65.1162790698%)
# 4-10 comments & backer category 3 & pledge category 1 & level category 2 = 12 (27.9069767442%)
# 11-20 comments & backer category 3 & pledge category 1 & level category 2 = 3 (6.97674418605%)
# 21-30 comments & backer category 3 & pledge category 1 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 3 & pledge category 1 & level category 2 = 0 (0.0%)
#
# 0-3 comments & backer category 3 & pledge category 1 & level category 3 = 4 (28.5714285714%)
# 4-10 comments & backer category 3 & pledge category 1 & level category 3 = 6 (42.8571428571%)
# 11-20 comments & backer category 3 & pledge category 1 & level category 3 = 3 (21.4285714286%)
# 21-30 comments & backer category 3 & pledge category 1 & level category 3 = 1 (7.14285714286%)
# 30+ comments & backer category 3 & pledge category 1 & level category 3 = 0 (0.0%)
#
# 0-3 comments & backer category 3 & pledge category 2 & level category 1 = 88 (73.3333333333%)
# 4-10 comments & backer category 3 & pledge category 2 & level category 1 = 28 (23.3333333333%)
# 11-20 comments & backer category 3 & pledge category 2 & level category 1 = 3 (2.5%)
# 21-30 comments & backer category 3 & pledge category 2 & level category 1 = 0 (0.0%)
# 30+ comments & backer category 3 & pledge category 2 & level category 1 = 1 (0.833333333333%)
#
# 0-3 comments & backer category 3 & pledge category 2 & level category 2 = 6 (40.0%)
# 4-10 comments & backer category 3 & pledge category 2 & level category 2 = 7 (46.6666666667%)
# 11-20 comments & backer category 3 & pledge category 2 & level category 2 = 2 (13.3333333333%)
# 21-30 comments & backer category 3 & pledge category 2 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 3 & pledge category 2 & level category 2 = 0 (0.0%)
#
# 0-3 comments & backer category 3 & pledge category 2 & level category 3 = 4 (66.6666666667%)
# 4-10 comments & backer category 3 & pledge category 2 & level category 3 = 1 (16.6666666667%)
# 11-20 comments & backer category 3 & pledge category 2 & level category 3 = 0 (0.0%)
# 21-30 comments & backer category 3 & pledge category 2 & level category 3 = 1 (16.6666666667%)
# 30+ comments & backer category 3 & pledge category 2 & level category 3 = 0 (0.0%)
#
# 0-3 comments & backer category 4 & pledge category 1 & level category 1 = 34 (40.4761904762%)
# 4-10 comments & backer category 4 & pledge category 1 & level category 1 = 38 (45.2380952381%)
# 11-20 comments & backer category 4 & pledge category 1 & level category 1 = 11 (13.0952380952%)
# 21-30 comments & backer category 4 & pledge category 1 & level category 1 = 1 (1.19047619048%)
# 30+ comments & backer category 4 & pledge category 1 & level category 1 = 0 (0.0%)
#
# 0-3 comments & backer category 4 & pledge category 1 & level category 2 = 9 (56.25%)
# 4-10 comments & backer category 4 & pledge category 1 & level category 2 = 4 (25.0%)
# 11-20 comments & backer category 4 & pledge category 1 & level category 2 = 3 (18.75%)
# 21-30 comments & backer category 4 & pledge category 1 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 4 & pledge category 1 & level category 2 = 0 (0.0%)
# 0-3 comments & backer category 4 & pledge category 1 & level category 3 = 1 (50.0%)
# 4-10 comments & backer category 4 & pledge category 1 & level category 3 = 1 (50.0%)
# 11-20 comments & backer category 4 & pledge category 1 & level category 3 = 0 (0.0%)
# 21-30 comments & backer category 4 & pledge category 1 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 4 & pledge category 1 & level category 3 = 0 (0.0%)
#
# 0-3 comments & backer category 4 & pledge category 2 & level category 1 = 46 (43.3962264151%)
# 4-10 comments & backer category 4 & pledge category 2 & level category 1 = 45 (42.4528301887%)
# 11-20 comments & backer category 4 & pledge category 2 & level category 1 = 13 (12.2641509434%)
# 21-30 comments & backer category 4 & pledge category 2 & level category 1 = 1 (0.943396226415%)
# 30+ comments & backer category 4 & pledge category 2 & level category 1 = 1 (0.943396226415%)
#
# 0-3 comments & backer category 4 & pledge category 2 & level category 2 = 7 (50.0%)
# 4-10 comments & backer category 4 & pledge category 2 & level category 2 = 4 (28.5714285714%)
# 11-20 comments & backer category 4 & pledge category 2 & level category 2 = 3 (21.4285714286%)
# 21-30 comments & backer category 4 & pledge category 2 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 4 & pledge category 2 & level category 2 = 0 (0.0%)
#
# 0-3 comments & backer category 4 & pledge category 2 & level category 3 = 3 (42.8571428571%)
# 4-10 comments & backer category 4 & pledge category 2 & level category 3 = 4 (57.1428571429%)
# 11-20 comments & backer category 4 & pledge category 2 & level category 3 = 0 (0.0%)
# 21-30 comments & backer category 4 & pledge category 2 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 4 & pledge category 2 & level category 3 = 0 (0.0%)
#
# 0-3 comments & backer category 5 & pledge category 1 & level category 1 = 10 (29.4117647059%)
# 4-10 comments & backer category 5 & pledge category 1 & level category 1 = 10 (29.4117647059%)
# 11-20 comments & backer category 5 & pledge category 1 & level category 1 = 9 (26.4705882353%)
# 21-30 comments & backer category 5 & pledge category 1 & level category 1 = 3 (8.82352941176%)
# 30+ comments & backer category 5 & pledge category 1 & level category 1 = 2 (5.88235294118%)
#
# 0-3 comments & backer category 5 & pledge category 1 & level category 2 = 2 (20.0%)
# 4-10 comments & backer category 5 & pledge category 1 & level category 2 = 7 (70.0%)
# 11-20 comments & backer category 5 & pledge category 1 & level category 2 = 0 (0.0%)
# 21-30 comments & backer category 5 & pledge category 1 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 5 & pledge category 1 & level category 2 = 1 (10.0%)
#
# 0-3 comments & backer category 5 & pledge category 1 & level category 3 = 1 (100.0%)
# 4-10 comments & backer category 5 & pledge category 1 & level category 3 = 0 (0.0%)
# 11-20 comments & backer category 5 & pledge category 1 & level category 3 = 0 (0.0%)
# 21-30 comments & backer category 5 & pledge category 1 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 5 & pledge category 1 & level category 3 = 0 (0.0%)
#
# 0-3 comments & backer category 5 & pledge category 2 & level category 1 = 71 (21.3213213213%)
# 4-10 comments & backer category 5 & pledge category 2 & level category 1 = 80 (24.024024024%)
# 11-20 comments & backer category 5 & pledge category 2 & level category 1 = 74 (22.2222222222%)
# 21-30 comments & backer category 5 & pledge category 2 & level category 1 = 29 (8.70870870871%)
# 30+ comments & backer category 5 & pledge category 2 & level category 1 = 75 (22.5225225225%)
#
# 0-3 comments & backer category 5 & pledge category 2 & level category 2 = 18 (14.8760330579%)
# 4-10 comments & backer category 5 & pledge category 2 & level category 2 = 45 (37.1900826446%)
# 11-20 comments & backer category 5 & pledge category 2 & level category 2 = 27 (22.3140495868%)
# 21-30 comments & backer category 5 & pledge category 2 & level category 2 = 12 (9.9173553719%)
# 30+ comments & backer category 5 & pledge category 2 & level category 2 = 19 (15.7024793388%)
#
# 0-3 comments & backer category 5 & pledge category 2 & level category 3 = 12 (17.1428571429%)
# 4-10 comments & backer category 5 & pledge category 2 & level category 3 = 17 (24.2857142857%)
# 11-20 comments & backer category 5 & pledge category 2 & level category 3 = 15 (21.4285714286%)
# 21-30 comments & backer category 5 & pledge category 2 & level category 3 = 8 (11.4285714286%)
# 30+ comments & backer category 5 & pledge category 2 & level category 3 = 17 (24.2857142857%)

# %% [markdown]
# ### unsuccessful_projects_df['pledges_bin'] = unsuccessful_projects_df.pledged.apply(assign_pledges_bin_for_project)
# unsuccessful_projects_df['levels_bin'] = unsuccessful_projects_df.levels_count.apply(assign_bin_for_unsuccessful_project)
# unsuccessful_projects_df['backers_bin'] = unsuccessful_projects_df.backers_count.apply(assign_backers_bin_for_successful_or_unsuccessful_project)
#
# fig, ax = plt.subplots(nrows=6, ncols=5)
# fig.set_size_inches(18.5,10.5)
#
# unsuccessful_projects_df_by_backers_pledges_and_levels = unsuccessful_projects_df[['backers_bin', 'pledges_bin', 'levels_bin', 'comments_count']].set_index(['backers_bin', 'pledges_bin', 'levels_bin'])
# grid = [(level_category+1, pledge_category+1, backer_category+1) for backer_category in range(5) for pledge_category in range(2) for level_category in range(3)]
# for (i, (level_category, pledge_category, backer_category)) in enumerate(grid):
#     try:
#         df = unsuccessful_projects_df_by_backers_pledges_and_levels.ix[backer_category].ix[pledge_category].ix[level_category]
#         df.hist(ax=ax[i/5, i%5])
#         ax[i/5, i%5].set_title('Unsuccessful Projects \n# Comments at \nBacker Category {0}\n Pledge Category {1}\n Level Category {2}'.format(backer_category, pledge_category, level_category))
#     except BaseException:
#         print (i/5, i%5)
#         ax[i/5, i%5].set_title('Unuccessful Projects \n# Comments at \nBacker Category {0}\n Pledge Category {1}\n Level Category {2}'.format(backer_category, pledge_category, level_category))
#         continue

# %%
unsuccessful_comments_categories = ['0-2 comments', '3-10 comments', '11-29 comments', '30+ comments']
unsuccessful_comments_ranges = [(0,2), (3,11), (11,30), (30, np.inf)]

print '# unsuccessful projects subject to:'

for backer_category in range(5):
    
    for pledge_category in range(2):
        
        for level_category in range(3):
            print
            for (unsuccessful_comments_category, unsuccessful_comments_range) in zip(unsuccessful_comments_categories, unsuccessful_comments_ranges):

                try:
                    df = unsuccessful_projects_df_by_backers_pledges_and_levels.ix[backer_category+1].ix[pledge_category+1].ix[level_category+1]
                    inrange_indices = (df >= min(unsuccessful_comments_range)).values & (df < max(unsuccessful_comments_range)).values
                    n = len(df[inrange_indices])
                    prob = 100.0*n/len(df)
                    print '{5} & backer category {0} & pledge category {1} & level category {2} = {3} ({4}%)'.format(backer_category+1,
                                                                                                                                                 pledge_category+1,
                                                                                                                                                 level_category+1,
                                                                                                                                                 n, prob, unsuccessful_comments_category)
                    
                except BaseException as detail:
                    print '{5} & backer category {0} & pledge category {1} & level category {2} = {3} ({4}%)'.format(backer_category+1,
                                                                                                                                                 pledge_category+1,
                                                                                                                                                 level_category+1,
                                                                                                                                                 0, 0.0, unsuccessful_comments_category)
# Out:
# # unsuccessful projects subject to:
#
# 0-2 comments & backer category 1 & pledge category 1 & level category 1 = 1178 (91.3178294574%)
# 3-10 comments & backer category 1 & pledge category 1 & level category 1 = 54 (4.18604651163%)
# 11-29 comments & backer category 1 & pledge category 1 & level category 1 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 1 & level category 1 = 0 (0.0%)
#
# 0-2 comments & backer category 1 & pledge category 1 & level category 2 = 268 (91.7808219178%)
# 3-10 comments & backer category 1 & pledge category 1 & level category 2 = 11 (3.76712328767%)
# 11-29 comments & backer category 1 & pledge category 1 & level category 2 = 1 (0.342465753425%)
# 30+ comments & backer category 1 & pledge category 1 & level category 2 = 0 (0.0%)
#
# 0-2 comments & backer category 1 & pledge category 1 & level category 3 = 57 (89.0625%)
# 3-10 comments & backer category 1 & pledge category 1 & level category 3 = 4 (6.25%)
# 11-29 comments & backer category 1 & pledge category 1 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 1 & level category 3 = 0 (0.0%)
#
# 0-2 comments & backer category 1 & pledge category 2 & level category 1 = 4 (80.0%)
# 3-10 comments & backer category 1 & pledge category 2 & level category 1 = 1 (20.0%)
# 11-29 comments & backer category 1 & pledge category 2 & level category 1 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 2 & level category 1 = 0 (0.0%)
#
# 0-2 comments & backer category 1 & pledge category 2 & level category 2 = 2 (66.6666666667%)
# 3-10 comments & backer category 1 & pledge category 2 & level category 2 = 1 (33.3333333333%)
# 11-29 comments & backer category 1 & pledge category 2 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 2 & level category 2 = 0 (0.0%)
# 0-2 comments & backer category 1 & pledge category 2 & level category 3 = 0 (0.0%)
# 3-10 comments & backer category 1 & pledge category 2 & level category 3 = 2 (100.0%)
# 11-29 comments & backer category 1 & pledge category 2 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 1 & pledge category 2 & level category 3 = 0 (0.0%)
#
# 0-2 comments & backer category 2 & pledge category 1 & level category 1 = 64 (57.1428571429%)
# 3-10 comments & backer category 2 & pledge category 1 & level category 1 = 27 (24.1071428571%)
# 11-29 comments & backer category 2 & pledge category 1 & level category 1 = 1 (0.892857142857%)
# 30+ comments & backer category 2 & pledge category 1 & level category 1 = 1 (0.892857142857%)
#
# 0-2 comments & backer category 2 & pledge category 1 & level category 2 = 8 (33.3333333333%)
# 3-10 comments & backer category 2 & pledge category 1 & level category 2 = 11 (45.8333333333%)
# 11-29 comments & backer category 2 & pledge category 1 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 2 & pledge category 1 & level category 2 = 0 (0.0%)
#
# 0-2 comments & backer category 2 & pledge category 1 & level category 3 = 6 (75.0%)
# 3-10 comments & backer category 2 & pledge category 1 & level category 3 = 1 (12.5%)
# 11-29 comments & backer category 2 & pledge category 1 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 2 & pledge category 1 & level category 3 = 0 (0.0%)
#
# 0-2 comments & backer category 2 & pledge category 2 & level category 1 = 3 (37.5%)
# 3-10 comments & backer category 2 & pledge category 2 & level category 1 = 2 (25.0%)
# 11-29 comments & backer category 2 & pledge category 2 & level category 1 = 2 (25.0%)
# 30+ comments & backer category 2 & pledge category 2 & level category 1 = 0 (0.0%)
# 0-2 comments & backer category 2 & pledge category 2 & level category 2 = 6 (75.0%)
# 3-10 comments & backer category 2 & pledge category 2 & level category 2 = 2 (25.0%)
# 11-29 comments & backer category 2 & pledge category 2 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 2 & pledge category 2 & level category 2 = 0 (0.0%)
#
# 0-2 comments & backer category 2 & pledge category 2 & level category 3 = 1 (100.0%)
# 3-10 comments & backer category 2 & pledge category 2 & level category 3 = 0 (0.0%)
# 11-29 comments & backer category 2 & pledge category 2 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 2 & pledge category 2 & level category 3 = 0 (0.0%)
#
# 0-2 comments & backer category 3 & pledge category 1 & level category 1 = 5 (23.8095238095%)
# 3-10 comments & backer category 3 & pledge category 1 & level category 1 = 10 (47.619047619%)
# 11-29 comments & backer category 3 & pledge category 1 & level category 1 = 3 (14.2857142857%)
# 30+ comments & backer category 3 & pledge category 1 & level category 1 = 0 (0.0%)
#
# 0-2 comments & backer category 3 & pledge category 1 & level category 2 = 5 (33.3333333333%)
# 3-10 comments & backer category 3 & pledge category 1 & level category 2 = 7 (46.6666666667%)
# 11-29 comments & backer category 3 & pledge category 1 & level category 2 = 2 (13.3333333333%)
# 30+ comments & backer category 3 & pledge category 1 & level category 2 = 0 (0.0%)
#
# 0-2 comments & backer category 3 & pledge category 1 & level category 3 = 1 (100.0%)
# 3-10 comments & backer category 3 & pledge category 1 & level category 3 = 0 (0.0%)
# 11-29 comments & backer category 3 & pledge category 1 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 3 & pledge category 1 & level category 3 = 0 (0.0%)
#
# 0-2 comments & backer category 3 & pledge category 2 & level category 1 = 1 (16.6666666667%)
# 3-10 comments & backer category 3 & pledge category 2 & level category 1 = 2 (33.3333333333%)
# 11-29 comments & backer category 3 & pledge category 2 & level category 1 = 2 (33.3333333333%)
# 30+ comments & backer category 3 & pledge category 2 & level category 1 = 0 (0.0%)
#
# 0-2 comments & backer category 3 & pledge category 2 & level category 2 = 0 (0.0%)
# 3-10 comments & backer category 3 & pledge category 2 & level category 2 = 0 (0.0%)
# 11-29 comments & backer category 3 & pledge category 2 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 3 & pledge category 2 & level category 2 = 0 (0.0%)
#
# 0-2 comments & backer category 3 & pledge category 2 & level category 3 = 2 (50.0%)
# 3-10 comments & backer category 3 & pledge category 2 & level category 3 = 2 (50.0%)
# 11-29 comments & backer category 3 & pledge category 2 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 3 & pledge category 2 & level category 3 = 0 (0.0%)
#
# 0-2 comments & backer category 4 & pledge category 1 & level category 1 = 1 (50.0%)
# 3-10 comments & backer category 4 & pledge category 1 & level category 1 = 1 (50.0%)
# 11-29 comments & backer category 4 & pledge category 1 & level category 1 = 0 (0.0%)
# 30+ comments & backer category 4 & pledge category 1 & level category 1 = 0 (0.0%)
#
# 0-2 comments & backer category 4 & pledge category 1 & level category 2 = 0 (0.0%)
# 3-10 comments & backer category 4 & pledge category 1 & level category 2 = 1 (100.0%)
# 11-29 comments & backer category 4 & pledge category 1 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 4 & pledge category 1 & level category 2 = 0 (0.0%)
#
# 0-2 comments & backer category 4 & pledge category 1 & level category 3 = 0 (0.0%)
# 3-10 comments & backer category 4 & pledge category 1 & level category 3 = 0 (0.0%)
# 11-29 comments & backer category 4 & pledge category 1 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 4 & pledge category 1 & level category 3 = 0 (0.0%)
#
# 0-2 comments & backer category 4 & pledge category 2 & level category 1 = 3 (37.5%)
# 3-10 comments & backer category 4 & pledge category 2 & level category 1 = 3 (37.5%)
# 11-29 comments & backer category 4 & pledge category 2 & level category 1 = 0 (0.0%)
# 30+ comments & backer category 4 & pledge category 2 & level category 1 = 1 (12.5%)
#
# 0-2 comments & backer category 4 & pledge category 2 & level category 2 = 0 (0.0%)
# 3-10 comments & backer category 4 & pledge category 2 & level category 2 = 0 (0.0%)
# 11-29 comments & backer category 4 & pledge category 2 & level category 2 = 1 (50.0%)
# 30+ comments & backer category 4 & pledge category 2 & level category 2 = 0 (0.0%)
#
# 0-2 comments & backer category 4 & pledge category 2 & level category 3 = 2 (66.6666666667%)
# 3-10 comments & backer category 4 & pledge category 2 & level category 3 = 1 (33.3333333333%)
# 11-29 comments & backer category 4 & pledge category 2 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 4 & pledge category 2 & level category 3 = 0 (0.0%)
#
# 0-2 comments & backer category 5 & pledge category 1 & level category 1 = 1 (20.0%)
# 3-10 comments & backer category 5 & pledge category 1 & level category 1 = 3 (60.0%)
# 11-29 comments & backer category 5 & pledge category 1 & level category 1 = 0 (0.0%)
# 30+ comments & backer category 5 & pledge category 1 & level category 1 = 0 (0.0%)
#
# 0-2 comments & backer category 5 & pledge category 1 & level category 2 = 0 (0.0%)
# 3-10 comments & backer category 5 & pledge category 1 & level category 2 = 0 (0.0%)
# 11-29 comments & backer category 5 & pledge category 1 & level category 2 = 0 (0.0%)
# 30+ comments & backer category 5 & pledge category 1 & level category 2 = 0 (0.0%)
#
# 0-2 comments & backer category 5 & pledge category 1 & level category 3 = 0 (0.0%)
# 3-10 comments & backer category 5 & pledge category 1 & level category 3 = 0 (0.0%)
# 11-29 comments & backer category 5 & pledge category 1 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 5 & pledge category 1 & level category 3 = 0 (0.0%)
#
# 0-2 comments & backer category 5 & pledge category 2 & level category 1 = 3 (42.8571428571%)
# 3-10 comments & backer category 5 & pledge category 2 & level category 1 = 2 (28.5714285714%)
# 11-29 comments & backer category 5 & pledge category 2 & level category 1 = 1 (14.2857142857%)
# 30+ comments & backer category 5 & pledge category 2 & level category 1 = 1 (14.2857142857%)
# 0-2 comments & backer category 5 & pledge category 2 & level category 2 = 0 (0.0%)
# 3-10 comments & backer category 5 & pledge category 2 & level category 2 = 4 (66.6666666667%)
# 11-29 comments & backer category 5 & pledge category 2 & level category 2 = 1 (16.6666666667%)
# 30+ comments & backer category 5 & pledge category 2 & level category 2 = 0 (0.0%)
#
# 0-2 comments & backer category 5 & pledge category 2 & level category 3 = 0 (0.0%)
# 3-10 comments & backer category 5 & pledge category 2 & level category 3 = 1 (100.0%)
# 11-29 comments & backer category 5 & pledge category 2 & level category 3 = 0 (0.0%)
# 30+ comments & backer category 5 & pledge category 2 & level category 3 = 0 (0.0%)

# %% [markdown]
# ### Create Conditional Probability Tables

# %%
# Class referes to if the project is Successful or Failed

CLASS = dict({
    's' : 0.4,
    'f' : 0.6
})

GOAL_GIVEN_CLASS_CPT = dict({
    ('f', 1) : 0.083,
    ('f', 2) : 0.5682,
    ('f', 3) : 0.1717,
    ('f', 4) : 0.1559,
    ('f', 5) : 0.0205,
    ('f', 6) : 0.0005,
    ('s', 1) : 0.1141,
    ('s', 2) : 0.6076,
    ('s', 3) : 0.1390,
    ('s', 4) : 0.1166,
    ('s', 5) : 0.0215,
    ('s', 6) : 0.0011
})

DURATION_GIVEN_CLASS = dict({
    ('s', 1) : 0.30,
    ('s', 2) : 0.50,
    ('s', 3) : 0.20,
    ('f', 1) : 0.25,
    ('f', 2) : 0.50,
    ('f', 3) : 0.25
})

BACKERS_GIVEN_CLASS = dict({
    ('s', 1) : 0.1869,
    ('s', 2) : 0.2757,
    ('s', 3) : 0.1882,
    ('s', 4) : 0.1002,
    ('s', 5) : 0.0630,
    ('f', 1) : 0.8720,
    ('f', 2) : 0.0848,
    ('f', 3) : 0.0247,
    ('f', 4) : 0.0084,
    ('f', 5) : 0.0047
})

LEVELS_GIVEN_CLASS = dict({
    ('s', 1) : 0.68,
    ('s', 2) : 0.27,
    ('s', 3) : 0.05,
    ('f', 1) : 0.68,
    ('f', 2) : 0.27,
    ('f', 3) : 0.05
})

UPDATES_GIVEN_LEVEL_AND_CLASS = dict({
    ('s', 1, 1) : 0.7697,
    ('s', 1, 2) : 0.1723,
    ('s', 1, 3) : 0.0434,
    ('s', 1, 4) : 0.0145,
    ('s', 2, 1) : 0.7272,
    ('s', 2, 2) : 0.1896,
    ('s', 2, 3) : 0.0468,
    ('s', 2, 4) : 0.0364,
    ('s', 3, 1) : 0.5484,
    ('s', 3, 2) : 0.2984,
    ('s', 3, 3) : 0.0806,
    ('s', 3, 4) : 0.0726,
    ('b', 1, 1) : 0.9153,
    ('b', 1, 2) : 0.0628,
    ('b', 1, 3) : 0.0219,
    ('b', 2, 1) : 0.8946,
    ('b', 2, 2) : 0.0741,
    ('b', 2, 3) : 0.0313,
    ('b', 3, 1) : 0.6905,
    ('b', 3, 2) : 0.2024,
    ('b', 3, 3) : 0.1071
})

PLEDGES_GIVEN_BACKERS_AND_CLASS = dict({
    ('s', 1, 1) : 0.9766,
    ('s', 1, 2) : 0.0234,
    ('s', 2, 1) : 0.8380,
    ('s', 2, 2) : 0.1619,
    ('s', 3, 1) : 0.6721,
    ('s', 3, 2) : 0.3279,
    ('s', 4, 1) : 0.4454,
    ('s', 4, 2) : 0.5546,
    ('s', 5, 1) : 0.0791,
    ('s', 5, 2) : 0.9209,
    ('f', 1, 1) : 0.9940,
    ('f', 1, 2) : 0.0060,
    ('f', 2, 1) : 0.8944,
    ('f', 2, 2) : 0.1056,
    ('f', 3, 1) : 0.7872,
    ('f', 3, 2) : 0.2128,
    ('f', 4, 1) : 0.1875,
    ('f', 4, 2) : 0.8125,
    ('f', 5, 1) : 0.2632,
    ('f', 5, 2) : 0.7368
})

COMMENTS_GIVEN_BACKERS_AND_PLEDGES_AND_LEVELS_AND_CLASS = dict({
    ('s', 1, 1, 1, 1) : 0.9037,
    ('s', 1, 1, 1, 2) : 0.0870,
    ('s', 1, 1, 1, 3) : 0.0093,
    ('s', 1, 1, 1, 4) : 0.0001,
    ('s', 1, 1, 1, 5) : 0.0001,
    ('s', 1, 1, 2, 1) : 0.9213,
    ('s', 1, 1, 2, 2) : 0.0674,
    ('s', 1, 1, 2, 3) : 0.0011,
    ('s', 1, 1, 2, 4) : 0.0001,
    ('s', 1, 1, 2, 5) : 0.0001,
    ('s', 1, 1, 3, 1) : 0.6666,
    ('s', 1, 1, 3, 2) : 0.3333,
    ('s', 1, 1, 3, 3) : 0.0001,
    ('s', 1, 1, 3, 4) : 0.0001,
    ('s', 1, 1, 3, 5) : 0.0001,
    ('s', 1, 2, 1, 1) : 0.8000,
    ('s', 1, 2, 1, 2) : 0.1000,
    ('s', 1, 2, 1, 3) : 0.1000,
    ('s', 1, 2, 1, 4) : 0.0001,
    ('s', 1, 2, 1, 5) : 0.0001,
    ('s', 1, 2, 2, 1) : 0.0001,
    ('s', 1, 2, 2, 2) : 0.0001,
    ('s', 1, 2, 2, 3) : 0.0001,
    ('s', 1, 2, 2, 4) : 0.0001,
    ('s', 1, 2, 2, 5) : 0.0001,
    ('s', 1, 2, 3, 1) : 0.0001,
    ('s', 1, 2, 3, 2) : 0.0001,
    ('s', 1, 2, 3, 3) : 0.0001,
    ('s', 1, 2, 3, 4) : 0.0001,
    ('s', 1, 2, 3, 5) : 0.0001,
    ('s', 2, 1, 1, 1) : 0.7863,
    ('s', 2, 1, 1, 2) : 0.1960,
    ('s', 2, 1, 1, 3) : 0.0176,
    ('s', 2, 1, 1, 4) : 0.0001,
    ('s', 2, 1, 1, 5) : 0.0001,
    ('s', 2, 1, 2, 1) : 0.7500,
    ('s', 2, 1, 2, 2) : 0.2000,
    ('s', 2, 1, 2, 3) : 0.0500,
    ('s', 2, 1, 2, 4) : 0.0001,
    ('s', 2, 1, 2, 5) : 0.0001,
    ('s', 2, 1, 3, 1) : 0.8571,
    ('s', 2, 1, 3, 2) : 0.0001,
    ('s', 2, 1, 3, 3) : 0.1429,
    ('s', 2, 1, 3, 4) : 0.0001,
    ('s', 2, 1, 3, 5) : 0.0001,
    ('s', 2, 2, 1, 1) : 0.8025,
    ('s', 2, 2, 1, 2) : 0.1975,
    ('s', 2, 2, 1, 3) : 0.0001,
    ('s', 2, 2, 1, 4) : 0.0001,
    ('s', 2, 2, 1, 5) : 0.0001,
    ('s', 2, 2, 2, 1) : 0.6471,
    ('s', 2, 2, 2, 2) : 0.3529,
    ('s', 2, 2, 2, 3) : 0.0001,
    ('s', 2, 2, 2, 4) : 0.0001,
    ('s', 2, 2, 2, 5) : 0.0001,
    ('s', 2, 2, 3, 1) : 0.5000,
    ('s', 2, 2, 3, 2) : 0.5000,
    ('s', 2, 2, 3, 3) : 0.0001,
    ('s', 2, 2, 3, 4) : 0.0001,
    ('s', 2, 2, 3, 5) : 0.0001,
    ('s', 3, 1, 1, 1) : 0.6552,
    ('s', 3, 1, 1, 2) : 0.2672,
    ('s', 3, 1, 1, 3) : 0.0647,
    ('s', 3, 1, 1, 4) : 0.0086,
    ('s', 3, 1, 1, 5) : 0.0043,
    ('s', 3, 1, 2, 1) : 0.6512,
    ('s', 3, 1, 2, 2) : 0.2791,
    ('s', 3, 1, 2, 3) : 0.0700,
    ('s', 3, 1, 2, 4) : 0.0001,
    ('s', 3, 1, 2, 5) : 0.0001,
    ('s', 3, 1, 3, 1) : 0.2857,
    ('s', 3, 1, 3, 2) : 0.4286,
    ('s', 3, 1, 3, 3) : 0.2143,
    ('s', 3, 1, 3, 4) : 0.0714,
    ('s', 3, 1, 3, 5) : 0.0001,
    ('s', 3, 2, 1, 1) : 0.7333,
    ('s', 3, 2, 1, 2) : 0.2333,
    ('s', 3, 2, 1, 3) : 0.0250,
    ('s', 3, 2, 1, 4) : 0.0001,
    ('s', 3, 2, 1, 5) : 0.0083,
    ('s', 3, 2, 2, 1) : 0.4000,
    ('s', 3, 2, 2, 2) : 0.4667,
    ('s', 3, 2, 2, 3) : 0.1333,
    ('s', 3, 2, 2, 4) : 0.0001,
    ('s', 3, 2, 2, 5) : 0.0001,
    ('s', 3, 2, 3, 1) : 0.6667,
    ('s', 3, 2, 3, 2) : 0.1667,
    ('s', 3, 2, 3, 3) : 0.0001,
    ('s', 3, 2, 3, 4) : 0.1667,
    ('s', 3, 2, 3, 5) : 0.0001,
    ('s', 4, 1, 1, 1) : 0.4048,
    ('s', 4, 1, 1, 2) : 0.4524,
    ('s', 4, 1, 1, 3) : 0.1310,
    ('s', 4, 1, 1, 4) : 0.0190,
    ('s', 4, 1, 1, 5) : 0.0001,
    ('s', 4, 1, 2, 1) : 0.5625,
    ('s', 4, 1, 2, 2) : 0.2500,
    ('s', 4, 1, 2, 3) : 0.1875,
    ('s', 4, 1, 2, 4) : 0.0001,
    ('s', 4, 1, 2, 5) : 0.0001,
    ('s', 4, 1, 3, 1) : 0.5000,
    ('s', 4, 1, 3, 2) : 0.5000,
    ('s', 4, 1, 3, 3) : 0.0001,
    ('s', 4, 1, 3, 4) : 0.0001,
    ('s', 4, 1, 3, 5) : 0.0001,
    ('s', 4, 2, 1, 1) : 0.4340,
    ('s', 4, 2, 1, 2) : 0.4245,
    ('s', 4, 2, 1, 3) : 0.1226,
    ('s', 4, 2, 1, 4) : 0.0094,
    ('s', 4, 2, 1, 5) : 0.0094,
    ('s', 4, 2, 2, 1) : 0.5000,
    ('s', 4, 2, 2, 2) : 0.2857,
    ('s', 4, 2, 2, 3) : 0.2143,
    ('s', 4, 2, 2, 4) : 0.0001,
    ('s', 4, 2, 2, 5) : 0.0001,
    ('s', 4, 2, 3, 1) : 0.4286,
    ('s', 4, 2, 3, 2) : 0.5714,
    ('s', 4, 2, 3, 3) : 0.0001,
    ('s', 4, 2, 3, 4) : 0.0001,
    ('s', 4, 2, 3, 5) : 0.0001,
    ('s', 5, 1, 1, 1) : 0.2941,
    ('s', 5, 1, 1, 2) : 0.2941,
    ('s', 5, 1, 1, 3) : 0.2647,
    ('s', 5, 1, 1, 4) : 0.0882,
    ('s', 5, 1, 1, 5) : 0.0588,
    ('s', 5, 1, 2, 1) : 0.2000,
    ('s', 5, 1, 2, 2) : 0.7000,
    ('s', 5, 1, 2, 3) : 0.0001,
    ('s', 5, 1, 2, 4) : 0.0001,
    ('s', 5, 1, 2, 5) : 0.1000,
    ('s', 5, 1, 3, 1) : 1.0000,
    ('s', 5, 1, 3, 2) : 0.0001,
    ('s', 5, 1, 3, 3) : 0.0001,
    ('s', 5, 1, 3, 4) : 0.0001,
    ('s', 5, 1, 3, 5) : 0.0001,
    ('s', 5, 2, 1, 1) : 0.2132,
    ('s', 5, 2, 1, 2) : 0.2402,
    ('s', 5, 2, 1, 3) : 0.2222,
    ('s', 5, 2, 1, 4) : 0.0871,
    ('s', 5, 2, 1, 5) : 0.2252,
    ('s', 5, 2, 2, 1) : 0.1488,
    ('s', 5, 2, 2, 2) : 0.3719,
    ('s', 5, 2, 2, 3) : 0.2231,
    ('s', 5, 2, 2, 4) : 0.0992,
    ('s', 5, 2, 2, 5) : 0.1570,
    ('s', 5, 2, 3, 1) : 0.1714,
    ('s', 5, 2, 3, 2) : 0.2429,
    ('s', 5, 2, 3, 3) : 0.2143,
    ('s', 5, 2, 3, 4) : 0.1143,
    ('s', 5, 2, 3, 5) : 0.2429
})
